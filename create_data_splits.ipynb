# %% [markdown]
# **The purpose of this notebook is to generate the following datasets per ontology**:
#
# **TRAIN**: Used for training the PFP models
# **DEV**: Used for tuning model architecture and hyperparameters beta and gamma.
# **TEST**: Use for evaluation and benchmarking
# **PLASMODIUM HOLDOUT**: Used for evaluating the model on manually curated Plamsodium functions and set FDR thresholds

# %%
import numpy as np
import pandas as pd
import os 
import networkx as nx
import obonet
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
from Bio import SeqIO
from collections import defaultdict
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import MultiLabelBinarizer
from tqdm import tqdm
from collections import Counter
import subprocess
import requests, sys
import json
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#set seed for reproducibility
np.random.seed(42)

# %% [markdown]
# Read in the raw datasets

# %%
SAR_MA_AA_path = "/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/SAR_MA_AA.tsv"
Plasmodium_AA_path = "/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/Plasmodium_AA.tsv"
Plasmodium_MA_path = "/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/Plasmodium_MA.tsv"
SAR_MA_path = "/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/SAR_MA.tsv"

#read in the datasets
SAR_MA_AA = pd.read_csv(SAR_MA_AA_path, sep="\t")
Plasmodium_AA = pd.read_csv(Plasmodium_AA_path, sep="\t")
Plasmodium_MA = pd.read_csv(Plasmodium_MA_path, sep="\t")
SAR_MA = pd.read_csv(SAR_MA_path, sep="\t")
print("SAR_MA_AA:", SAR_MA_AA.shape)
print("Plasmodium_AA:", Plasmodium_AA.shape)
print("Plasmodium_MA:", Plasmodium_MA.shape)
print("SAR_MA:", SAR_MA.shape)

#assert columns are the same
assert SAR_MA_AA.columns.tolist() == Plasmodium_AA.columns.tolist() == Plasmodium_MA.columns.tolist() == SAR_MA.columns.tolist()
# Out:
# SAR_MA_AA: (791306, 9)
# Plasmodium_AA: (102355, 9)
# Plasmodium_MA: (1527, 9)
# SAR_MA: (11957, 9)

# %%
os.chdir('./raw_data_from_uniprot')

# %%
def create_seq_records(data):
    seq_records = []
    for index, row in data.iterrows():
        seq_record = SeqRecord(Seq(row['Sequence']), id=row['Entry'], description=row['Organism'])
        seq_records.append(seq_record)
    assert len(seq_records) == data.shape[0]
    return seq_records

# %%
#first create a column in dataset1 called GOAssertion 
SAR_MA_AA["GOAssertion"] = np.nan 
Plasmodium_AA["GOAssertion"] = "AA"

SAR_MA_AA.loc[SAR_MA_AA["Entry"].isin(SAR_MA["Entry"]), "GOAssertion"] = "MA"
SAR_MA_AA.loc[SAR_MA_AA["GOAssertion"].isnull(), "GOAssertion"] = "AA"

# %%
total_SAR = pd.concat([SAR_MA_AA, Plasmodium_AA])
total_SAR_function = total_SAR[total_SAR["Gene Ontology (molecular function)"].notnull()]
total_SAR_process = total_SAR[total_SAR["Gene Ontology (biological process)"].notnull()]
total_SAR_component = total_SAR[total_SAR["Gene Ontology (cellular component)"].notnull()]

print(total_SAR_function.shape, total_SAR_process.shape, total_SAR_component.shape)
# Out:
# (716735, 10) (573293, 10) (630944, 10)

# %%
total_SAR_records = create_seq_records(total_SAR)
print(len(total_SAR_records))
# Out:
# 893661

# %%
SeqIO.write(total_SAR_records, "total_SAR.fasta", "fasta")
# Out:
# 893661

# %%
seq_records_SAR_function = create_seq_records(total_SAR_function)
seq_records_SAR_process = create_seq_records(total_SAR_process)
seq_records_SAR_component = create_seq_records(total_SAR_component)

assert len(seq_records_SAR_function) == total_SAR_function.shape[0]
assert len(seq_records_SAR_process) == total_SAR_process.shape[0]
assert len(seq_records_SAR_component) == total_SAR_component.shape[0]

# %%
SeqIO.write(seq_records_SAR_function, "total_SAR_function_for_reduce.fasta", "fasta")
SeqIO.write(seq_records_SAR_process, "total_SAR_process_for_reduce.fasta", "fasta")
SeqIO.write(seq_records_SAR_component, "total_SAR_component_for_reduce.fasta", "fasta")
# Out:
# 630944

# %%
#run raw_data_from_uniprot/mmseq_cluster.sh

subprocess.run(["./mmseq_cluster.sh", "-h"])
# Out:
# Usage: ./mmseq_cluster.sh <parent_directory> <function_file> <component_file> <process_file> <min_seq_id>
# CompletedProcess(args=['./mmseq_cluster.sh', '-h'], returncode=1)

# %%
subprocess.run(["./mmseq_cluster.sh", "reduced_90", "total_SAR_function_for_reduce.fasta", "total_SAR_component_for_reduce.fasta", "total_SAR_process_for_reduce.fasta", "0.9"])
# Out:
# Creating databases...
# createdb /Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/total_SAR_function_for_reduce.fasta function/function_redundant_db
#
# MMseqs Version:       	14.7e284
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [=======================================================================
# Time for merging to function_redundant_db_h: 0h 0m 0s 118ms
# Time for merging to function_redundant_db: 0h 0m 0s 250ms
# Database type: Aminoacid
# Time for processing: 0h 0m 2s 130ms
# createdb /Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/total_SAR_component_for_reduce.fasta component/component_redundant_db
#
# MMseqs Version:       	14.7e284
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [===============================================================
# Time for merging to component_redundant_db_h: 0h 0m 0s 105ms
# Time for merging to component_redundant_db: 0h 0m 0s 220ms
# Database type: Aminoacid
# Time for processing: 0h 0m 1s 805ms
# createdb /Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/total_SAR_process_for_reduce.fasta process/process_redundant_db
#
# MMseqs Version:       	14.7e284
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [=========================================================
# Time for merging to process_redundant_db_h: 0h 0m 0s 101ms
# Time for merging to process_redundant_db: 0h 0m 0s 199ms
# Database type: Aminoacid
# Time for processing: 0h 0m 1s 617ms
# Clustering sequences...
# Create directory tmp
# cluster function/function_redundant_db function/function_clusters_redundant tmp --min-seq-id 0.9 -c 0.5 --cov-mode 1
#
# MMseqs Version:                     	14.7e284
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.5
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	10
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.9
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 1.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 1
# linclust function/function_redundant_db tmp/9696200901604251854/clu_redundancy tmp/9696200901604251854/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher function/function_redundant_db tmp/9696200901604251854/linclust/14271651232352195491/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# kmermatcher function/function_redundant_db tmp/9696200901604251854/linclust/14271651232352195491/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# Database size: 716735 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 716.73K 1s 723ms
# Sort kmer 0h 0m 0s 353ms
# Sort by rep. sequence 0h 0m 0s 147ms
# Time for fill: 0h 0m 0s 183ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 2s 704ms
# rescorediagonal function/function_redundant_db function/function_redundant_db tmp/9696200901604251854/linclust/14271651232352195491/pref tmp/9696200901604251854/linclust/14271651232352195491/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 716.73K 0s 308ms
# Time for merging to pref_rescore1: 0h 0m 0s 255ms
# Time for processing: 0h 0m 0s 746ms
# clust function/function_redundant_db tmp/9696200901604251854/linclust/14271651232352195491/pref_rescore1 tmp/9696200901604251854/linclust/14271651232352195491/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 104ms
#
# Size of the sequence database: 716735
# Size of the alignment database: 716735
# Number of clusters: 413197
#
# Writing results 0h 0m 0s 109ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 285ms
# createsubdb tmp/9696200901604251854/linclust/14271651232352195491/order_redundancy function/function_redundant_db tmp/9696200901604251854/linclust/14271651232352195491/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 141ms
# createsubdb tmp/9696200901604251854/linclust/14271651232352195491/order_redundancy tmp/9696200901604251854/linclust/14271651232352195491/pref tmp/9696200901604251854/linclust/14271651232352195491/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 158ms
# filterdb tmp/9696200901604251854/linclust/14271651232352195491/pref_filter1 tmp/9696200901604251854/linclust/14271651232352195491/pref_filter2 --filter-file tmp/9696200901604251854/linclust/14271651232352195491/order_redundancy --threads 10 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 413.20K 0s 140ms
# Time for merging to pref_filter2: 0h 0m 0s 166ms
# Time for processing: 0h 0m 0s 467ms
# rescorediagonal tmp/9696200901604251854/linclust/14271651232352195491/input_step_redundancy tmp/9696200901604251854/linclust/14271651232352195491/input_step_redundancy tmp/9696200901604251854/linclust/14271651232352195491/pref_filter2 tmp/9696200901604251854/linclust/14271651232352195491/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 413.20K 0s 198ms
# Time for merging to pref_rescore2: 0h 0m 0s 236ms
# Time for processing: 0h 0m 0s 572ms
# align tmp/9696200901604251854/linclust/14271651232352195491/input_step_redundancy tmp/9696200901604251854/linclust/14271651232352195491/input_step_redundancy tmp/9696200901604251854/linclust/14271651232352195491/pref_rescore2 tmp/9696200901604251854/linclust/14271651232352195491/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 413197 type: Aminoacid
# Target database size: 413197 type: Aminoacid
# Calculation of alignments
# [=================================================================] 413.20K 26s 810ms
# Time for merging to aln: 0h 0m 0s 134ms
# 856321 alignments calculated
# 483273 sequence pairs passed the thresholds (0.564360 of overall calculated)
# 1.169595 hits per query sequence
# Time for processing: 0h 0m 27s 65ms
# clust tmp/9696200901604251854/linclust/14271651232352195491/input_step_redundancy tmp/9696200901604251854/linclust/14271651232352195491/aln tmp/9696200901604251854/linclust/14271651232352195491/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 94ms
#
# Size of the sequence database: 413197
# Size of the alignment database: 413197
# Number of clusters: 362510
#
# Writing results 0h 0m 0s 92ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 236ms
# mergeclusters function/function_redundant_db tmp/9696200901604251854/clu_redundancy tmp/9696200901604251854/linclust/14271651232352195491/pre_clust tmp/9696200901604251854/linclust/14271651232352195491/clust --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 413.20K 0s 44ms
# Clustering step 2
# [=================================================================] 362.51K 0s 96ms
# Write merged clustering
# [=================================================================] 716.73K 0s 163ms
# Time for merging to clu_redundancy: 0h 0m 0s 135ms
# Time for processing: 0h 0m 0s 432ms
# createsubdb tmp/9696200901604251854/clu_redundancy function/function_redundant_db tmp/9696200901604251854/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 137ms
# prefilter tmp/9696200901604251854/input_step_redundancy tmp/9696200901604251854/input_step_redundancy tmp/9696200901604251854/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 362510 type: Aminoacid
# Estimated memory consumption: 2G
# Target database size: 362510 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 362.51K 2s 598ms
# Index table: Masked residues: 2925683
# Index table: fill
# [=================================================================] 362.51K 2s 550ms
# Index statistics
# Entries:          73974763
# DB size:          911 MB
# Avg k-mer size:   1.155856
# Top 10 k-mers
#     FAGTGK	2414
#     AYQGKT	2204
#     WWARVW	1580
#     PTFYQY	1368
#     HRLPLL	1134
#     GPGGLL	1040
#     LGGFVY	1019
#     GQGGYT	928
#     YGTSTY	897
#     LYPGKT	835
# Time for index table init: 0h 0m 5s 661ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 362510
# Target db start 1 to 362510
# [=================================================================] 362.51K 7s 855ms
#
# 2.038547 k-mers per position
# 3064 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 17 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 115ms
# Time for processing: 0h 0m 13s 994ms
# align tmp/9696200901604251854/input_step_redundancy tmp/9696200901604251854/input_step_redundancy tmp/9696200901604251854/pref_step0 tmp/9696200901604251854/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 362510 type: Aminoacid
# Target database size: 362510 type: Aminoacid
# Calculation of alignments
# [=================================================================] 362.51K 7m 30s 621ms
# Time for merging to aln_step0: 0h 0m 0s 322ms
# 5765293 alignments calculated
# 391673 sequence pairs passed the thresholds (0.067936 of overall calculated)
# 1.080447 hits per query sequence
# Time for processing: 0h 7m 31s 126ms
# clust tmp/9696200901604251854/input_step_redundancy tmp/9696200901604251854/aln_step0 tmp/9696200901604251854/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 276ms
#
# Size of the sequence database: 362510
# Size of the alignment database: 362510
# Number of clusters: 352585
#
# Writing results 0h 0m 0s 91ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 622ms
# mergeclusters function/function_redundant_db function/function_clusters_redundant tmp/9696200901604251854/clu_redundancy tmp/9696200901604251854/clu_step0 --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 362.51K 0s 36ms
# Clustering step 2
# [=================================================================] 352.58K 0s 157ms
# Write merged clustering
# [=================================================================] 716.73K 0s 238ms
# Time for merging to function_clusters_redundant: 0h 0m 0s 295ms
# Time for processing: 0h 0m 0s 900ms
# cluster component/component_redundant_db component/component_clusters_redundant tmp --min-seq-id 0.9 -c 0.5 --cov-mode 1
#
# MMseqs Version:                     	14.7e284
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.5
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	10
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.9
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 1.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 1
# linclust component/component_redundant_db tmp/12400988725396477983/clu_redundancy tmp/12400988725396477983/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher component/component_redundant_db tmp/12400988725396477983/linclust/3242237169228371394/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# kmermatcher component/component_redundant_db tmp/12400988725396477983/linclust/3242237169228371394/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# Database size: 630944 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 630.94K 1s 113ms
# Sort kmer 0h 0m 0s 391ms
# Sort by rep. sequence 0h 0m 0s 136ms
# Time for fill: 0h 0m 0s 154ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 2s 66ms
# rescorediagonal component/component_redundant_db component/component_redundant_db tmp/12400988725396477983/linclust/3242237169228371394/pref tmp/12400988725396477983/linclust/3242237169228371394/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 630.94K 0s 241ms
# Time for merging to pref_rescore1: 0h 0m 0s 409ms
# Time for processing: 0h 0m 0s 813ms
# clust component/component_redundant_db tmp/12400988725396477983/linclust/3242237169228371394/pref_rescore1 tmp/12400988725396477983/linclust/3242237169228371394/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 96ms
#
# Size of the sequence database: 630944
# Size of the alignment database: 630944
# Number of clusters: 358277
#
# Writing results 0h 0m 0s 94ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 292ms
# createsubdb tmp/12400988725396477983/linclust/3242237169228371394/order_redundancy component/component_redundant_db tmp/12400988725396477983/linclust/3242237169228371394/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 126ms
# createsubdb tmp/12400988725396477983/linclust/3242237169228371394/order_redundancy tmp/12400988725396477983/linclust/3242237169228371394/pref tmp/12400988725396477983/linclust/3242237169228371394/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 139ms
# filterdb tmp/12400988725396477983/linclust/3242237169228371394/pref_filter1 tmp/12400988725396477983/linclust/3242237169228371394/pref_filter2 --filter-file tmp/12400988725396477983/linclust/3242237169228371394/order_redundancy --threads 10 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 358.28K 0s 115ms
# Time for merging to pref_filter2: 0h 0m 0s 148ms
# Time for processing: 0h 0m 0s 407ms
# rescorediagonal tmp/12400988725396477983/linclust/3242237169228371394/input_step_redundancy tmp/12400988725396477983/linclust/3242237169228371394/input_step_redundancy tmp/12400988725396477983/linclust/3242237169228371394/pref_filter2 tmp/12400988725396477983/linclust/3242237169228371394/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 358.28K 0s 155ms
# Time for merging to pref_rescore2: 0h 0m 0s 153ms
# Time for processing: 0h 0m 0s 457ms
# align tmp/12400988725396477983/linclust/3242237169228371394/input_step_redundancy tmp/12400988725396477983/linclust/3242237169228371394/input_step_redundancy tmp/12400988725396477983/linclust/3242237169228371394/pref_rescore2 tmp/12400988725396477983/linclust/3242237169228371394/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 358277 type: Aminoacid
# Target database size: 358277 type: Aminoacid
# Calculation of alignments
# [=================================================================] 358.28K 20s 915ms
# Time for merging to aln: 0h 0m 0s 116ms
# 728286 alignments calculated
# 418670 sequence pairs passed the thresholds (0.574870 of overall calculated)
# 1.168565 hits per query sequence
# Time for processing: 0h 0m 21s 135ms
# clust tmp/12400988725396477983/linclust/3242237169228371394/input_step_redundancy tmp/12400988725396477983/linclust/3242237169228371394/aln tmp/12400988725396477983/linclust/3242237169228371394/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 277ms
#
# Size of the sequence database: 358277
# Size of the alignment database: 358277
# Number of clusters: 315024
#
# Writing results 0h 0m 0s 78ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 624ms
# mergeclusters component/component_redundant_db tmp/12400988725396477983/clu_redundancy tmp/12400988725396477983/linclust/3242237169228371394/pre_clust tmp/12400988725396477983/linclust/3242237169228371394/clust --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 358.28K 0s 29ms
# Clustering step 2
# [=================================================================] 315.02K 0s 140ms
# Write merged clustering
# [=================================================================] 630.94K 0s 202ms
# Time for merging to clu_redundancy: 0h 0m 0s 158ms
# Time for processing: 0h 0m 0s 535ms
# createsubdb tmp/12400988725396477983/clu_redundancy component/component_redundant_db tmp/12400988725396477983/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 117ms
# prefilter tmp/12400988725396477983/input_step_redundancy tmp/12400988725396477983/input_step_redundancy tmp/12400988725396477983/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 315024 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 315024 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 315.02K 2s 396ms
# Index table: Masked residues: 2743359
# Index table: fill
# [=================================================================] 315.02K 1s 327ms
# Index statistics
# Entries:          60688137
# DB size:          835 MB
# Avg k-mer size:   0.948252
# Top 10 k-mers
#     LRDWNR	2191
#     AYQGKT	1872
#     WWARVW	1581
#     PTFYQY	1368
#     GPGGLL	834
#     GQGGHT	823
#     GQGGYT	752
#     YGTSTY	725
#     PQLWEW	669
#     NYKRWW	662
# Time for index table init: 0h 0m 4s 123ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 315024
# Target db start 1 to 315024
# [=================================================================] 315.02K 5s 627ms
#
# 2.010304 k-mers per position
# 2446 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 16 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 102ms
# Time for processing: 0h 0m 10s 209ms
# align tmp/12400988725396477983/input_step_redundancy tmp/12400988725396477983/input_step_redundancy tmp/12400988725396477983/pref_step0 tmp/12400988725396477983/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 315024 type: Aminoacid
# Target database size: 315024 type: Aminoacid
# Calculation of alignments
# [=================================================================] 315.02K 6m 0s 752ms
# Time for merging to aln_step0: 0h 0m 0s 102ms
# 4800201 alignments calculated
# 341848 sequence pairs passed the thresholds (0.071215 of overall calculated)
# 1.085149 hits per query sequence
# Time for processing: 0h 6m 1s 12ms
# clust tmp/12400988725396477983/input_step_redundancy tmp/12400988725396477983/aln_step0 tmp/12400988725396477983/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 108ms
#
# Size of the sequence database: 315024
# Size of the alignment database: 315024
# Number of clusters: 306559
#
# Writing results 0h 0m 0s 75ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 324ms
# mergeclusters component/component_redundant_db component/component_clusters_redundant tmp/12400988725396477983/clu_redundancy tmp/12400988725396477983/clu_step0 --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 315.02K 0s 30ms
# Clustering step 2
# [=================================================================] 306.56K 0s 73ms
# Write merged clustering
# [=================================================================] 630.94K 0s 128ms
# Time for merging to component_clusters_redundant: 0h 0m 0s 291ms
# Time for processing: 0h 0m 0s 536ms
# cluster process/process_redundant_db process/process_clusters_redundant tmp --min-seq-id 0.9 -c 0.5 --cov-mode 1
#
# MMseqs Version:                     	14.7e284
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.5
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	10
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.9
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 1.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 1
# linclust process/process_redundant_db tmp/8656781693095139340/clu_redundancy tmp/8656781693095139340/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher process/process_redundant_db tmp/8656781693095139340/linclust/9215862896326619405/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# kmermatcher process/process_redundant_db tmp/8656781693095139340/linclust/9215862896326619405/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# Database size: 573293 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 573.29K 1s 100ms
# Sort kmer 0h 0m 0s 251ms
# Sort by rep. sequence 0h 0m 0s 120ms
# Time for fill: 0h 0m 0s 140ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 1s 886ms
# rescorediagonal process/process_redundant_db process/process_redundant_db tmp/8656781693095139340/linclust/9215862896326619405/pref tmp/8656781693095139340/linclust/9215862896326619405/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 573.29K 0s 260ms
# Time for merging to pref_rescore1: 0h 0m 0s 477ms
# Time for processing: 0h 0m 0s 921ms
# clust process/process_redundant_db tmp/8656781693095139340/linclust/9215862896326619405/pref_rescore1 tmp/8656781693095139340/linclust/9215862896326619405/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 117ms
#
# Size of the sequence database: 573293
# Size of the alignment database: 573293
# Number of clusters: 326620
#
# Writing results 0h 0m 0s 84ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 426ms
# createsubdb tmp/8656781693095139340/linclust/9215862896326619405/order_redundancy process/process_redundant_db tmp/8656781693095139340/linclust/9215862896326619405/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 118ms
# createsubdb tmp/8656781693095139340/linclust/9215862896326619405/order_redundancy tmp/8656781693095139340/linclust/9215862896326619405/pref tmp/8656781693095139340/linclust/9215862896326619405/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 123ms
# filterdb tmp/8656781693095139340/linclust/9215862896326619405/pref_filter1 tmp/8656781693095139340/linclust/9215862896326619405/pref_filter2 --filter-file tmp/8656781693095139340/linclust/9215862896326619405/order_redundancy --threads 10 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 326.62K 0s 105ms
# Time for merging to pref_filter2: 0h 0m 0s 172ms
# Time for processing: 0h 0m 0s 421ms
# rescorediagonal tmp/8656781693095139340/linclust/9215862896326619405/input_step_redundancy tmp/8656781693095139340/linclust/9215862896326619405/input_step_redundancy tmp/8656781693095139340/linclust/9215862896326619405/pref_filter2 tmp/8656781693095139340/linclust/9215862896326619405/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 326.62K 0s 142ms
# Time for merging to pref_rescore2: 0h 0m 0s 152ms
# Time for processing: 0h 0m 0s 447ms
# align tmp/8656781693095139340/linclust/9215862896326619405/input_step_redundancy tmp/8656781693095139340/linclust/9215862896326619405/input_step_redundancy tmp/8656781693095139340/linclust/9215862896326619405/pref_rescore2 tmp/8656781693095139340/linclust/9215862896326619405/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 326620 type: Aminoacid
# Target database size: 326620 type: Aminoacid
# Calculation of alignments
# [=================================================================] 326.62K 20s 268ms
# Time for merging to aln: 0h 0m 0s 99ms
# 671644 alignments calculated
# 380954 sequence pairs passed the thresholds (0.567196 of overall calculated)
# 1.166352 hits per query sequence
# Time for processing: 0h 0m 20s 486ms
# clust tmp/8656781693095139340/linclust/9215862896326619405/input_step_redundancy tmp/8656781693095139340/linclust/9215862896326619405/aln tmp/8656781693095139340/linclust/9215862896326619405/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 30ms
#
# Size of the sequence database: 326620
# Size of the alignment database: 326620
# Number of clusters: 287208
#
# Writing results 0h 0m 0s 92ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 164ms
# mergeclusters process/process_redundant_db tmp/8656781693095139340/clu_redundancy tmp/8656781693095139340/linclust/9215862896326619405/pre_clust tmp/8656781693095139340/linclust/9215862896326619405/clust --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 326.62K 0s 35ms
# Clustering step 2
# [=================================================================] 287.21K 0s 71ms
# Write merged clustering
# [=================================================================] 573.29K 0s 124ms
# Time for merging to clu_redundancy: 0h 0m 0s 162ms
# Time for processing: 0h 0m 0s 408ms
# createsubdb tmp/8656781693095139340/clu_redundancy process/process_redundant_db tmp/8656781693095139340/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 109ms
# prefilter tmp/8656781693095139340/input_step_redundancy tmp/8656781693095139340/input_step_redundancy tmp/8656781693095139340/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 287208 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 287208 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 287.21K 1s 825ms
# Index table: Masked residues: 2414592
# Index table: fill
# [=================================================================] 287.21K 1s 311ms
# Index statistics
# Entries:          57624967
# DB size:          818 MB
# Avg k-mer size:   0.900390
# Top 10 k-mers
#     FAGTGK	2408
#     AYQGKT	2199
#     GQGGYT	927
#     YGTSTY	897
#     SMNGTN	757
#     GQGGFT	723
#     HIYDLT	573
#     HVYDLT	568
#     KNGCCW	461
#     LGGFVY	432
# Time for index table init: 0h 0m 3s 550ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 287208
# Target db start 1 to 287208
# [=================================================================] 287.21K 5s 300ms
#
# 1.961322 k-mers per position
# 2357 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 17 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 94ms
# Time for processing: 0h 0m 9s 310ms
# align tmp/8656781693095139340/input_step_redundancy tmp/8656781693095139340/input_step_redundancy tmp/8656781693095139340/pref_step0 tmp/8656781693095139340/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 287208 type: Aminoacid
# Target database size: 287208 type: Aminoacid
# Calculation of alignments
# [=================================================================] 287.21K 5m 58s 490ms
# Time for merging to aln_step0: 0h 0m 0s 168ms
# 4452585 alignments calculated
# 310352 sequence pairs passed the thresholds (0.069702 of overall calculated)
# 1.080583 hits per query sequence
# Time for processing: 0h 5m 58s 830ms
# clust tmp/8656781693095139340/input_step_redundancy tmp/8656781693095139340/aln_step0 tmp/8656781693095139340/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 31ms
#
# Size of the sequence database: 287208
# Size of the alignment database: 287208
# Number of clusters: 279340
#
# Writing results 0h 0m 0s 69ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 134ms
# mergeclusters process/process_redundant_db process/process_clusters_redundant tmp/8656781693095139340/clu_redundancy tmp/8656781693095139340/clu_step0 --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 287.21K 0s 26ms
# Clustering step 2
# [=================================================================] 279.34K 0s 133ms
# Write merged clustering
# [=================================================================] 573.29K 0s 244ms
# Time for merging to process_clusters_redundant: 0h 0m 0s 291ms
# Time for processing: 0h 0m 0s 858ms
# Creating TSV files...
# createtsv function/function_redundant_db function/function_redundant_db function/function_clusters_redundant function/function_clusters_redundant.tsv
#
# MMseqs Version:                 	14.7e284
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	10
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to function_clusters_redundant.tsv: 0h 0m 0s 321ms
# Time for processing: 0h 0m 0s 720ms
# createtsv component/component_redundant_db component/component_redundant_db component/component_clusters_redundant component/component_clusters_redundant.tsv
#
# MMseqs Version:                 	14.7e284
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	10
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to component_clusters_redundant.tsv: 0h 0m 0s 103ms
# Time for processing: 0h 0m 0s 313ms
# createtsv process/process_redundant_db process/process_redundant_db process/process_clusters_redundant process/process_clusters_redundant.tsv
#
# MMseqs Version:                 	14.7e284
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	10
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to process_clusters_redundant.tsv: 0h 0m 0s 100ms
# Time for processing: 0h 0m 0s 257ms
# All tasks completed successfully.
# CompletedProcess(args=['./mmseq_cluster.sh', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/total_SAR_function_for_reduce.fasta', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/total_SAR_component_for_reduce.fasta', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/total_SAR_process_for_reduce.fasta', '0.9'], returncode=0)

# %% [markdown]
# # Pick cluster representatives from reduced dataset (0.9)

# %%
SAR_function_clusters = pd.read_csv('reduced_90/function/function_clusters_redundant.tsv', sep='\t', header=None)
SAR_function_clusters.columns = ["Cluster", "Entry"]
SAR_process_clusters = pd.read_csv('reduced_90/process/process_clusters_redundant.tsv', sep='\t', header=None)
SAR_process_clusters.columns = ["Cluster", "Entry"]
SAR_component_clusters = pd.read_csv('reduced_90/component/component_clusters_redundant.tsv', sep='\t', header=None)
SAR_component_clusters.columns = ["Cluster", "Entry"]

print(SAR_function_clusters.shape)
print(SAR_process_clusters.shape)
print(SAR_component_clusters.shape)

assert SAR_function_clusters["Entry"].isin(total_SAR_function["Entry"]).all()
assert SAR_process_clusters["Entry"].isin(total_SAR_process["Entry"]).all()
assert SAR_component_clusters["Entry"].isin(total_SAR_component["Entry"]).all()
# Out:
# (716735, 2)
# (573293, 2)
# (630944, 2)

# %%
total_SAR_function_merged = pd.merge(total_SAR_function, SAR_function_clusters, on="Entry") 
total_SAR_process_merged = pd.merge(total_SAR_process, SAR_process_clusters, on="Entry")
total_SAR_component_merged = pd.merge(total_SAR_component, SAR_component_clusters, on="Entry")

total_SAR_function_merged_grouped = total_SAR_function_merged.groupby("Cluster")
total_SAR_process_merged_grouped = total_SAR_process_merged.groupby("Cluster")
total_SAR_component_merged_grouped = total_SAR_component_merged.groupby("Cluster")

total_SAR_function_GO = total_SAR_function_merged_grouped.apply(lambda x: x.loc[x['Gene Ontology (molecular function)'].str.findall(r"GO:\d+").str.len().idxmax()])
total_SAR_process_GO = total_SAR_process_merged_grouped.apply(lambda x: x.loc[x['Gene Ontology (biological process)'].str.findall(r"GO:\d+").str.len().idxmax()])
total_SAR_component_GO = total_SAR_component_merged_grouped.apply(lambda x: x.loc[x['Gene Ontology (cellular component)'].str.findall(r"GO:\d+").str.len().idxmax()])

print(total_SAR_function_GO.shape)
print(total_SAR_process_GO.shape)
print(total_SAR_component_GO.shape)

total_SAR_function_GO_terms = total_SAR_function_GO["Gene Ontology (molecular function)"].str.findall(r"GO:\d+")
total_SAR_process_GO_terms = total_SAR_process_GO["Gene Ontology (biological process)"].str.findall(r"GO:\d+")
total_SAR_component_GO_terms = total_SAR_component_GO["Gene Ontology (cellular component)"].str.findall(r"GO:\d+")
# Out:
# (352585, 11)
# (279340, 11)
# (306559, 11)

# %% [markdown]
# save

# %%
#create fasta records for total_SAR_function_GO, total_SAR_process_GO, total_SAR_component_GO
seq_records_SAR_function_GO = create_seq_records(total_SAR_function_GO)
seq_records_SAR_process_GO = create_seq_records(total_SAR_process_GO)
seq_records_SAR_component_GO = create_seq_records(total_SAR_component_GO)

assert len(seq_records_SAR_function_GO) == total_SAR_function_GO.shape[0]
assert len(seq_records_SAR_process_GO) == total_SAR_process_GO.shape[0]
assert len(seq_records_SAR_component_GO) == total_SAR_component_GO.shape[0]

#write 
function_path = "reduced_90_function.fasta"
process_path = "reduced_90_process.fasta"
component_path = "reduced_90_component.fasta"

SeqIO.write(seq_records_SAR_function_GO, function_path, "fasta")
SeqIO.write(seq_records_SAR_process_GO, process_path, "fasta")
SeqIO.write(seq_records_SAR_component_GO, component_path, "fasta")

#write tsv files
total_SAR_function_GO.to_csv("reduced_90_function.tsv", sep="\t", index=False)
total_SAR_process_GO.to_csv("reduced_90_process.tsv", sep="\t", index=False)
total_SAR_component_GO.to_csv("reduced_90_component.tsv", sep="\t", index=False)

#print out the shapes into a file 
with open('reduced_90_expected_shapes.txt', 'w') as f:
    print("Function:", total_SAR_function_GO.shape, file=f)
    print("Process:", total_SAR_process_GO.shape, file=f)
    print("Component:", total_SAR_component_GO.shape, file=f)

# %% [markdown]
# # Propogate

# %%
total_SAR_function_GO_raw_terms = total_SAR_function_GO['Gene Ontology (molecular function)'].str.findall(r"GO:\d+")
total_SAR_process_GO_raw_terms = total_SAR_process_GO['Gene Ontology (biological process)'].str.findall(r"GO:\d+")
total_SAR_component_GO_raw_terms = total_SAR_component_GO['Gene Ontology (cellular component)'].str.findall(r"GO:\d+")

total_SAR_function_GO['Raw GO terms'] = total_SAR_function_GO_raw_terms
total_SAR_process_GO['Raw GO terms'] = total_SAR_process_GO_raw_terms
total_SAR_component_GO['Raw GO terms'] = total_SAR_component_GO_raw_terms

# %%
#get unique terms 
def get_unique_go_terms(go_terms):
    return set([term for terms in go_terms for term in terms])

unique_go_terms_function = get_unique_go_terms(total_SAR_function_GO_raw_terms)
unique_go_terms_process = get_unique_go_terms(total_SAR_process_GO_raw_terms)
unique_go_terms_component = get_unique_go_terms(total_SAR_component_GO_raw_terms)

print("Unique GO terms in function:", len(unique_go_terms_function))
print("Unique GO terms in process:", len(unique_go_terms_process))
print("Unique GO terms in component:", len(unique_go_terms_component))

#conver to lists 
unique_go_terms_function = list(unique_go_terms_function)
unique_go_terms_process = list(unique_go_terms_process)
unique_go_terms_component = list(unique_go_terms_component)
# Out:
# Unique GO terms in function: 2608
# Unique GO terms in process: 2291
# Unique GO terms in component: 810

# %%
base_url = "https://www.ebi.ac.uk/QuickGO/services/ontology/go/terms"

# Function to get ancestors for a batch of GO terms and store the JSON response
def get_ancestors(go_terms_batch):
    terms = "%2C".join(go_terms_batch)  # Join the GO terms with URL-encoded commas
    request_url = f"{base_url}/{terms}/ancestors?relations=is_a"
    
    try:
        response = requests.get(request_url, headers={"Accept": "application/json"})
        response.raise_for_status()  # Raise exception if request failed

        data = response.json()
        
        # Build the ancestors dictionary for the batch
        ancestors_dict_batch = {}
        json_dict_batch = {}
        for result in data.get("results", []):
            term = result.get("id")
            ancestors = result.get("ancestors", [])
            ancestors_dict_batch[term] = ancestors if ancestors else None
            json_dict_batch[term] = result  # Store only the specific JSON data for each term

        return json_dict_batch, ancestors_dict_batch

    except requests.exceptions.RequestException as e:
        print(f"Error fetching ancestors for {go_terms_batch}: {e}")
        return None, None

def process_go_terms_in_batches(go_terms, batch_size=20):
    function_ancestors_dict = {}      
    function_json_dict = {}           

    # Split the GO terms into batches
    for i in tqdm(range(0, len(go_terms), batch_size)):
        batch = go_terms[i:i + batch_size]  # Get the current batch of GO terms
        json_data_batch, ancestors_dict_batch = get_ancestors(batch)

        # Update the dictionaries with the batch results
        if json_data_batch and ancestors_dict_batch:
            function_json_dict.update(json_data_batch)  # Store only the relevant JSON for each term
            function_ancestors_dict.update(ancestors_dict_batch)  # Store the ancestors

    return function_json_dict, function_ancestors_dict

batch_size = 50  

function_json_dict, function_ancestors_dict = process_go_terms_in_batches(unique_go_terms_function, batch_size=batch_size)

with open('function_ALL_data_ancestors_dict.json', 'w') as f:
    json.dump(function_ancestors_dict, f, indent=4)
with open('function_ALL_data_json_dict.json', 'w') as f:
    json.dump(function_json_dict, f, indent=4)


process_json_dict, process_ancestors_dict = process_go_terms_in_batches(unique_go_terms_process, batch_size=batch_size)
with open('process_ALL_data_ancestors_dict.json', 'w') as f:
    json.dump(process_ancestors_dict, f, indent=4)
with open('process_ALL_data_json_dict.json', 'w') as f:
    json.dump(process_json_dict, f, indent=4)

assert len(process_json_dict) == len(unique_go_terms_process)
assert len(process_ancestors_dict) == len(unique_go_terms_process)

component_json_dict, component_ancestors_dict = process_go_terms_in_batches(unique_go_terms_component, batch_size=batch_size)
with open('component_ALL_data_ancestors_dict.json', 'w') as f:
    json.dump(component_ancestors_dict, f, indent=4)
with open('component_ALL_data_json_dict.json', 'w') as f:
    json.dump(component_json_dict, f, indent=4)

assert len(component_json_dict) == len(unique_go_terms_component)
assert len(component_ancestors_dict) == len(unique_go_terms_component)
# Out:
# 100%|██████████| 53/53 [00:43<00:00,  1.22it/s]
# 100%|██████████| 46/46 [00:38<00:00,  1.18it/s]
# 100%|██████████| 17/17 [00:13<00:00,  1.26it/s]

# %%
function_OBSELETE = [term for term in function_json_dict if function_json_dict[term].get("isObsolete")]
process_OBSELETE = [term for term in process_json_dict if process_json_dict[term].get("isObsolete")]
component_OBSELETE = [term for term in component_json_dict if component_json_dict[term].get("isObsolete")]

print("Function Obselete:", len(function_OBSELETE))
print("Process Obselete:", len(process_OBSELETE))
print("Component Obselete:", len(component_OBSELETE))

#combine and set 
ALL_OBSELETE_TERMS = set(function_OBSELETE + process_OBSELETE + component_OBSELETE)

print("Total Obselete terms:", len(ALL_OBSELETE_TERMS))
# Out:
# Function Obselete: 53
# Process Obselete: 10
# Component Obselete: 12
# Total Obselete terms: 75

# %%
def add_ancestors(go_terms_list, ancestors_dict):
    all_ancestors = []
    
    for term_list in tqdm(go_terms_list, desc="Adding ancestors"):
        terms_return = set() 
        for t in term_list:
            # Check if the term exists in the dictionary and has valid ancestors
            if t in ancestors_dict and ancestors_dict[t] is not None:
                # Add ancestors, excluding the original term itself
                terms_return.update(a for a in ancestors_dict[t] if a != t)
        
        # Append the filtered ancestors found for this protein (as a list)
        all_ancestors.append(list(terms_return))

    return all_ancestors

total_SAR_function_GO_raw_terms_propogated = add_ancestors(list(total_SAR_function_GO_raw_terms), function_ancestors_dict)
total_SAR_process_GO_raw_terms_propogated = add_ancestors(list(total_SAR_process_GO_raw_terms), process_ancestors_dict)
total_SAR_component_GO_raw_terms_propogated = add_ancestors(list(total_SAR_component_GO_raw_terms), component_ancestors_dict)
# Out:
# Adding ancestors: 100%|██████████| 352585/352585 [00:00<00:00, 413121.88it/s]
# Adding ancestors: 100%|██████████| 279340/279340 [00:00<00:00, 355595.35it/s]
# Adding ancestors: 100%|██████████| 306559/306559 [00:00<00:00, 619003.57it/s]

# %%
#get the indicies for non-propogated terms (aka the len is 0)
non_propogated_function_terms = [i for i, x in enumerate(total_SAR_function_GO_raw_terms_propogated) if len(x) == 0]
non_propogated_process_terms = [i for i, x in enumerate(total_SAR_process_GO_raw_terms_propogated) if len(x) == 0]
non_propogated_component_terms = [i for i, x in enumerate(total_SAR_component_GO_raw_terms_propogated) if len(x) == 0]

print("Non-propogated function terms:", len(non_propogated_function_terms))
print("Non-propogated process terms:", len(non_propogated_process_terms))
print("Non-propogated component terms:", len(non_propogated_component_terms))
# Out:
# Non-propogated function terms: 86
# Non-propogated process terms: 260
# Non-propogated component terms: 1937

# %%
total_SAR_function_GO['Raw propagated GO terms'] = total_SAR_function_GO_raw_terms_propogated
total_SAR_process_GO['Raw propagated GO terms'] = total_SAR_process_GO_raw_terms_propogated
total_SAR_component_GO['Raw propagated GO terms'] = total_SAR_component_GO_raw_terms_propogated

# %%
#filter the dataframes to only include rows where the length of the Raw propagated GO terms is not zero 
total_SAR_function_GO = total_SAR_function_GO[total_SAR_function_GO['Raw propagated GO terms'].str.len() > 0]
total_SAR_process_GO = total_SAR_process_GO[total_SAR_process_GO['Raw propagated GO terms'].str.len() > 0]
total_SAR_component_GO = total_SAR_component_GO[total_SAR_component_GO['Raw propagated GO terms'].str.len() > 0]

# %%
seq_records_SAR_function_GO_propagated = create_seq_records(total_SAR_function_GO)
seq_records_SAR_process_GO_propagated = create_seq_records(total_SAR_process_GO)
seq_records_SAR_component_GO_propagated = create_seq_records(total_SAR_component_GO)

assert len(seq_records_SAR_function_GO_propagated) == total_SAR_function_GO.shape[0]
assert len(seq_records_SAR_process_GO_propagated) == total_SAR_process_GO.shape[0]
assert len(seq_records_SAR_component_GO_propagated) == total_SAR_component_GO.shape[0]

function_path = "reduced_90_function_propagated.fasta"
process_path = "reduced_90_process_propagated.fasta"
component_path = "reduced_90_component_propagated.fasta"

SeqIO.write(seq_records_SAR_function_GO_propagated, function_path, "fasta")
SeqIO.write(seq_records_SAR_process_GO_propagated, process_path, "fasta")
SeqIO.write(seq_records_SAR_component_GO_propagated, component_path, "fasta")

total_SAR_function_GO.to_csv("reduced_90_function_propagated.tsv", sep="\t", index=False)
total_SAR_process_GO.to_csv("reduced_90_process_propagated.tsv", sep="\t", index=False)
total_SAR_component_GO.to_csv("reduced_90_component_propagated.tsv", sep="\t", index=False)

with open('reduced_90_expected_shapes_propagated.txt', 'w') as f:
    print("Function:", total_SAR_function_GO.shape, file=f)
    print("Process:", total_SAR_process_GO.shape, file=f)
    print("Component:", total_SAR_component_GO.shape, file=f)

# %% [markdown]
# Now we can preform the sequence similarity splits for the train, dev, and test sets

# %%
#subprocess.run(["./mmseq_cluster.sh", "/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90", "/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/total_SAR_function_for_reduce.fasta", "/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/total_SAR_component_for_reduce.fasta", "/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/total_SAR_process_for_reduce.fasta", "0.9"])

subprocess.run(["./mmseq_cluster.sh", "reduced_90_similarity_30", "reduced_90_function_propagated.fasta", "reduced_90_component_propagated.fasta", "reduced_90_process_propagated.fasta", "0.3"])
# Out:
# Creating databases...
# createdb /Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_function_propagated.fasta function/function_redundant_db
#
# MMseqs Version:       	14.7e284
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [===================================
# Time for merging to function_redundant_db_h: 0h 0m 0s 62ms
# Time for merging to function_redundant_db: 0h 0m 0s 108ms
# Database type: Aminoacid
# Time for processing: 0h 0m 1s 237ms
# createdb /Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_component_propagated.fasta component/component_redundant_db
#
# MMseqs Version:       	14.7e284
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [==============================
# Time for merging to component_redundant_db_h: 0h 0m 0s 60ms
# Time for merging to component_redundant_db: 0h 0m 0s 117ms
# Database type: Aminoacid
# Time for processing: 0h 0m 1s 37ms
# createdb /Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_process_propagated.fasta process/process_redundant_db
#
# MMseqs Version:       	14.7e284
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [===========================
# Time for merging to process_redundant_db_h: 0h 0m 0s 51ms
# Time for merging to process_redundant_db: 0h 0m 0s 113ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 879ms
# Clustering sequences...
# Create directory tmp
# cluster function/function_redundant_db function/function_clusters_redundant tmp --min-seq-id 0.3 -c 0.5 --cov-mode 1
#
# MMseqs Version:                     	14.7e284
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.5
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	10
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.3
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 5.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 3
# linclust function/function_redundant_db tmp/7310995555670121402/clu_redundancy tmp/7310995555670121402/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher function/function_redundant_db tmp/7310995555670121402/linclust/11900443378622354739/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.3 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# kmermatcher function/function_redundant_db tmp/7310995555670121402/linclust/11900443378622354739/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.3 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# Database size: 352499 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 352.50K 0s 680ms
# Sort kmer 0h 0m 0s 160ms
# Sort by rep. sequence 0h 0m 0s 46ms
# Time for fill: 0h 0m 0s 95ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 1s 174ms
# rescorediagonal function/function_redundant_db function/function_redundant_db tmp/7310995555670121402/linclust/11900443378622354739/pref tmp/7310995555670121402/linclust/11900443378622354739/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 352.50K 0s 134ms
# Time for merging to pref_rescore1: 0h 0m 0s 145ms
# Time for processing: 0h 0m 0s 375ms
# clust function/function_redundant_db tmp/7310995555670121402/linclust/11900443378622354739/pref_rescore1 tmp/7310995555670121402/linclust/11900443378622354739/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 43ms
#
# Size of the sequence database: 352499
# Size of the alignment database: 352499
# Number of clusters: 240467
#
# Writing results 0h 0m 0s 62ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 144ms
# createsubdb tmp/7310995555670121402/linclust/11900443378622354739/order_redundancy function/function_redundant_db tmp/7310995555670121402/linclust/11900443378622354739/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 80ms
# createsubdb tmp/7310995555670121402/linclust/11900443378622354739/order_redundancy tmp/7310995555670121402/linclust/11900443378622354739/pref tmp/7310995555670121402/linclust/11900443378622354739/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 87ms
# filterdb tmp/7310995555670121402/linclust/11900443378622354739/pref_filter1 tmp/7310995555670121402/linclust/11900443378622354739/pref_filter2 --filter-file tmp/7310995555670121402/linclust/11900443378622354739/order_redundancy --threads 10 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 240.47K 0s 64ms
# Time for merging to pref_filter2: 0h 0m 0s 141ms
# Time for processing: 0h 0m 0s 318ms
# rescorediagonal tmp/7310995555670121402/linclust/11900443378622354739/input_step_redundancy tmp/7310995555670121402/linclust/11900443378622354739/input_step_redundancy tmp/7310995555670121402/linclust/11900443378622354739/pref_filter2 tmp/7310995555670121402/linclust/11900443378622354739/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 240.47K 0s 128ms
# Time for merging to pref_rescore2: 0h 0m 0s 130ms
# Time for processing: 0h 0m 0s 349ms
# align tmp/7310995555670121402/linclust/11900443378622354739/input_step_redundancy tmp/7310995555670121402/linclust/11900443378622354739/input_step_redundancy tmp/7310995555670121402/linclust/11900443378622354739/pref_rescore2 tmp/7310995555670121402/linclust/11900443378622354739/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 240467 type: Aminoacid
# Target database size: 240467 type: Aminoacid
# Calculation of alignments
# [=================================================================] 240.47K 35s 835ms
# Time for merging to aln: 0h 0m 0s 203ms
# 587088 alignments calculated
# 532946 sequence pairs passed the thresholds (0.907779 of overall calculated)
# 2.216296 hits per query sequence
# Time for processing: 0h 0m 36s 179ms
# clust tmp/7310995555670121402/linclust/11900443378622354739/input_step_redundancy tmp/7310995555670121402/linclust/11900443378622354739/aln tmp/7310995555670121402/linclust/11900443378622354739/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 91ms
#
# Size of the sequence database: 240467
# Size of the alignment database: 240467
# Number of clusters: 129277
#
# Writing results 0h 0m 0s 35ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 198ms
# mergeclusters function/function_redundant_db tmp/7310995555670121402/clu_redundancy tmp/7310995555670121402/linclust/11900443378622354739/pre_clust tmp/7310995555670121402/linclust/11900443378622354739/clust --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 240.47K 0s 22ms
# Clustering step 2
# [=================================================================] 129.28K 0s 44ms
# Write merged clustering
# [=================================================================] 352.50K 0s 98ms
# Time for merging to clu_redundancy: 0h 0m 0s 106ms
# Time for processing: 0h 0m 0s 287ms
# createsubdb tmp/7310995555670121402/clu_redundancy function/function_redundant_db tmp/7310995555670121402/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 56ms
# prefilter tmp/7310995555670121402/input_step_redundancy tmp/7310995555670121402/input_step_redundancy tmp/7310995555670121402/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 129277 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 129277 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 129.28K 0s 906ms
# Index table: Masked residues: 1472848
# Index table: fill
# [=================================================================] 129.28K 0s 663ms
# Index statistics
# Entries:          28536038
# DB size:          651 MB
# Avg k-mer size:   0.445876
# Top 10 k-mers
#     FAGTGK	753
#     AYQGKT	706
#     HRLPIL	384
#     LGGFVY	327
#     GQGGYT	301
#     GPGGTL	277
#     YGTSTY	273
#     VHDKNL	243
#     VHDKNV	233
#     GLNGCY	219
# Time for index table init: 0h 0m 1s 877ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 129277
# Target db start 1 to 129277
# [=================================================================] 129.28K 2s 257ms
#
# 2.099023 k-mers per position
# 977 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 11 sequences passed prefiltering per query sequence
# 11 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 47ms
# Time for processing: 0h 0m 4s 512ms
# align tmp/7310995555670121402/input_step_redundancy tmp/7310995555670121402/input_step_redundancy tmp/7310995555670121402/pref_step0 tmp/7310995555670121402/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 129277 type: Aminoacid
# Target database size: 129277 type: Aminoacid
# Calculation of alignments
# [=================================================================] 129.28K 1m 53s 438ms
# Time for merging to aln_step0: 0h 0m 0s 255ms
# 1318669 alignments calculated
# 755619 sequence pairs passed the thresholds (0.573016 of overall calculated)
# 5.844961 hits per query sequence
# Time for processing: 0h 1m 53s 809ms
# clust tmp/7310995555670121402/input_step_redundancy tmp/7310995555670121402/aln_step0 tmp/7310995555670121402/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 310ms
#
# Size of the sequence database: 129277
# Size of the alignment database: 129277
# Number of clusters: 63992
#
# Writing results 0h 0m 0s 18ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 602ms
# createsubdb tmp/7310995555670121402/clu_step0 tmp/7310995555670121402/input_step_redundancy tmp/7310995555670121402/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 29ms
# prefilter tmp/7310995555670121402/input_step1 tmp/7310995555670121402/input_step1 tmp/7310995555670121402/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 3 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 63992 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 63992 type: Aminoacid
# Index table k-mer threshold: 136 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 63.99K 0s 600ms
# Index table: Masked residues: 987445
# Index table: fill
# [=================================================================] 63.99K 0s 614ms
# Index statistics
# Entries:          30542156
# DB size:          663 MB
# Avg k-mer size:   0.477221
# Top 10 k-mers
#     IHDKNI	292
#     FAGTGK	279
#     AYQGKT	276
#     QTSKTM	218
#     KLLDGS	144
#     LGGFVY	141
#     SGTALP	121
#     GLNGCY	119
#     YGTSTY	118
#     IGGFVY	104
# Time for index table init: 0h 0m 1s 600ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 136
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 63992
# Target db start 1 to 63992
# [=================================================================] 63.99K 5s 947ms
#
# 20.735735 k-mers per position
# 4322 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 16 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 42ms
# Time for processing: 0h 0m 7s 944ms
# align tmp/7310995555670121402/input_step1 tmp/7310995555670121402/input_step1 tmp/7310995555670121402/pref_step1 tmp/7310995555670121402/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 63992 type: Aminoacid
# Target database size: 63992 type: Aminoacid
# Calculation of alignments
# [=================================================================] 63.99K 41s 969ms
# Time for merging to aln_step1: 0h 0m 0s 123ms
# 868675 alignments calculated
# 180523 sequence pairs passed the thresholds (0.207814 of overall calculated)
# 2.821024 hits per query sequence
# Time for processing: 0h 0m 42s 198ms
# clust tmp/7310995555670121402/input_step1 tmp/7310995555670121402/aln_step1 tmp/7310995555670121402/clu_step1 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 151ms
#
# Size of the sequence database: 63992
# Size of the alignment database: 63992
# Number of clusters: 42907
#
# Writing results 0h 0m 0s 11ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 282ms
# createsubdb tmp/7310995555670121402/clu_step1 tmp/7310995555670121402/input_step1 tmp/7310995555670121402/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 63ms
# prefilter tmp/7310995555670121402/input_step2 tmp/7310995555670121402/input_step2 tmp/7310995555670121402/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 5 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 42907 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 42907 type: Aminoacid
# Index table k-mer threshold: 118 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 42.91K 0s 500ms
# Index table: Masked residues: 812882
# Index table: fill
# [=================================================================] 42.91K 0s 488ms
# Index statistics
# Entries:          23484526
# DB size:          622 MB
# Avg k-mer size:   0.366946
# Top 10 k-mers
#     AYQGKT	203
#     IHDKNI	194
#     YRSLLL	159
#     QTSKTM	156
#     RDKELL	116
#     KLRLSL	115
#     SSSSSS	106
#     GQGGYT	99
#     GLNGCY	91
#     LGGFVY	89
# Time for index table init: 0h 0m 1s 317ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 118
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 42907
# Target db start 1 to 42907
# [=================================================================] 42.91K 19s 136ms
#
# 152.989696 k-mers per position
# 27203 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 19 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 166ms
# Time for processing: 0h 0m 20s 918ms
# align tmp/7310995555670121402/input_step2 tmp/7310995555670121402/input_step2 tmp/7310995555670121402/pref_step2 tmp/7310995555670121402/aln_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 42907 type: Aminoacid
# Target database size: 42907 type: Aminoacid
# Calculation of alignments
# [=================================================================] 42.91K 24s 325ms
# Time for merging to aln_step2: 0h 0m 0s 22ms
# 641657 alignments calculated
# 65787 sequence pairs passed the thresholds (0.102527 of overall calculated)
# 1.533246 hits per query sequence
# Time for processing: 0h 0m 24s 511ms
# clust tmp/7310995555670121402/input_step2 tmp/7310995555670121402/aln_step2 tmp/7310995555670121402/clu_step2 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 19ms
#
# Size of the sequence database: 42907
# Size of the alignment database: 42907
# Number of clusters: 36398
#
# Writing results 0h 0m 0s 9ms
# Time for merging to clu_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 35ms
# mergeclusters function/function_redundant_db function/function_clusters_redundant tmp/7310995555670121402/clu_redundancy tmp/7310995555670121402/clu_step0 tmp/7310995555670121402/clu_step1 tmp/7310995555670121402/clu_step2 --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 129.28K 0s 17ms
# Clustering step 2
# [=================================================================] 63.99K 0s 26ms
# Clustering step 3
# [=================================================================] 42.91K 0s 33ms
# Clustering step 4
# [=================================================================] 36.40K 0s 38ms
# Write merged clustering
# [=================================================================] 352.50K 0s 63ms
# Time for merging to function_clusters_redundant: 0h 0m 0s 49ms
# Time for processing: 0h 0m 0s 213ms
# cluster component/component_redundant_db component/component_clusters_redundant tmp --min-seq-id 0.3 -c 0.5 --cov-mode 1
#
# MMseqs Version:                     	14.7e284
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.5
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	10
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.3
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 5.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 3
# linclust component/component_redundant_db tmp/6254332096599620672/clu_redundancy tmp/6254332096599620672/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher component/component_redundant_db tmp/6254332096599620672/linclust/16851860129876914997/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.3 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# kmermatcher component/component_redundant_db tmp/6254332096599620672/linclust/16851860129876914997/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.3 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# Database size: 304622 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 304.62K 0s 560ms
# Sort kmer 0h 0m 0s 132ms
# Sort by rep. sequence 0h 0m 0s 41ms
# Time for fill: 0h 0m 0s 79ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 1s 7ms
# rescorediagonal component/component_redundant_db component/component_redundant_db tmp/6254332096599620672/linclust/16851860129876914997/pref tmp/6254332096599620672/linclust/16851860129876914997/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 304.62K 0s 110ms
# Time for merging to pref_rescore1: 0h 0m 0s 141ms
# Time for processing: 0h 0m 0s 376ms
# clust component/component_redundant_db tmp/6254332096599620672/linclust/16851860129876914997/pref_rescore1 tmp/6254332096599620672/linclust/16851860129876914997/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 34ms
#
# Size of the sequence database: 304622
# Size of the alignment database: 304622
# Number of clusters: 210629
#
# Writing results 0h 0m 0s 54ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 136ms
# createsubdb tmp/6254332096599620672/linclust/16851860129876914997/order_redundancy component/component_redundant_db tmp/6254332096599620672/linclust/16851860129876914997/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 72ms
# createsubdb tmp/6254332096599620672/linclust/16851860129876914997/order_redundancy tmp/6254332096599620672/linclust/16851860129876914997/pref tmp/6254332096599620672/linclust/16851860129876914997/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 107ms
# filterdb tmp/6254332096599620672/linclust/16851860129876914997/pref_filter1 tmp/6254332096599620672/linclust/16851860129876914997/pref_filter2 --filter-file tmp/6254332096599620672/linclust/16851860129876914997/order_redundancy --threads 10 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 210.63K 0s 62ms
# Time for merging to pref_filter2: 0h 0m 0s 207ms
# Time for processing: 0h 0m 0s 477ms
# rescorediagonal tmp/6254332096599620672/linclust/16851860129876914997/input_step_redundancy tmp/6254332096599620672/linclust/16851860129876914997/input_step_redundancy tmp/6254332096599620672/linclust/16851860129876914997/pref_filter2 tmp/6254332096599620672/linclust/16851860129876914997/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 210.63K 0s 111ms
# Time for merging to pref_rescore2: 0h 0m 0s 292ms
# Time for processing: 0h 0m 0s 537ms
# align tmp/6254332096599620672/linclust/16851860129876914997/input_step_redundancy tmp/6254332096599620672/linclust/16851860129876914997/input_step_redundancy tmp/6254332096599620672/linclust/16851860129876914997/pref_rescore2 tmp/6254332096599620672/linclust/16851860129876914997/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 210629 type: Aminoacid
# Target database size: 210629 type: Aminoacid
# Calculation of alignments
# [=================================================================] 210.63K 27s 956ms
# Time for merging to aln: 0h 0m 0s 69ms
# 488068 alignments calculated
# 443474 sequence pairs passed the thresholds (0.908632 of overall calculated)
# 2.105474 hits per query sequence
# Time for processing: 0h 0m 28s 102ms
# clust tmp/6254332096599620672/linclust/16851860129876914997/input_step_redundancy tmp/6254332096599620672/linclust/16851860129876914997/aln tmp/6254332096599620672/linclust/16851860129876914997/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 26ms
#
# Size of the sequence database: 210629
# Size of the alignment database: 210629
# Number of clusters: 118803
#
# Writing results 0h 0m 0s 32ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 82ms
# mergeclusters component/component_redundant_db tmp/6254332096599620672/clu_redundancy tmp/6254332096599620672/linclust/16851860129876914997/pre_clust tmp/6254332096599620672/linclust/16851860129876914997/clust --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 210.63K 0s 19ms
# Clustering step 2
# [=================================================================] 118.80K 0s 37ms
# Write merged clustering
# [=================================================================] 304.62K 0s 62ms
# Time for merging to clu_redundancy: 0h 0m 0s 252ms
# Time for processing: 0h 0m 0s 423ms
# createsubdb tmp/6254332096599620672/clu_redundancy component/component_redundant_db tmp/6254332096599620672/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 49ms
# prefilter tmp/6254332096599620672/input_step_redundancy tmp/6254332096599620672/input_step_redundancy tmp/6254332096599620672/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 118803 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 118803 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 118.80K 0s 872ms
# Index table: Masked residues: 1372997
# Index table: fill
# [=================================================================] 118.80K 0s 566ms
# Index statistics
# Entries:          24791509
# DB size:          630 MB
# Avg k-mer size:   0.387367
# Top 10 k-mers
#     FAGTGK	633
#     AYQGKT	619
#     VHDKNI	328
#     GQGGYT	276
#     YGTSTY	252
#     LGGFVY	209
#     PYDKRL	182
#     HVYDLT	170
#     HHPICV	157
#     VHDKNV	154
# Time for index table init: 0h 0m 1s 801ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 118803
# Target db start 1 to 118803
# [=================================================================] 118.80K 2s 1ms
#
# 2.048060 k-mers per position
# 817 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 10 sequences passed prefiltering per query sequence
# 8 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 49ms
# Time for processing: 0h 0m 4s 155ms
# align tmp/6254332096599620672/input_step_redundancy tmp/6254332096599620672/input_step_redundancy tmp/6254332096599620672/pref_step0 tmp/6254332096599620672/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 118803 type: Aminoacid
# Target database size: 118803 type: Aminoacid
# Calculation of alignments
# [=================================================================] 118.80K 1m 32s 287ms
# Time for merging to aln_step0: 0h 0m 0s 236ms
# 1072112 alignments calculated
# 619046 sequence pairs passed the thresholds (0.577408 of overall calculated)
# 5.210693 hits per query sequence
# Time for processing: 0h 1m 32s 666ms
# clust tmp/6254332096599620672/input_step_redundancy tmp/6254332096599620672/aln_step0 tmp/6254332096599620672/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 42ms
#
# Size of the sequence database: 118803
# Size of the alignment database: 118803
# Number of clusters: 62469
#
# Writing results 0h 0m 0s 17ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 224ms
# createsubdb tmp/6254332096599620672/clu_step0 tmp/6254332096599620672/input_step_redundancy tmp/6254332096599620672/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 26ms
# prefilter tmp/6254332096599620672/input_step1 tmp/6254332096599620672/input_step1 tmp/6254332096599620672/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 3 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 62469 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 62469 type: Aminoacid
# Index table k-mer threshold: 136 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 62.47K 0s 588ms
# Index table: Masked residues: 917307
# Index table: fill
# [=================================================================] 62.47K 0s 562ms
# Index statistics
# Entries:          28162202
# DB size:          649 MB
# Avg k-mer size:   0.440034
# Top 10 k-mers
#     AYQGKT	244
#     YRSLLL	213
#     QTSKTM	178
#     RDKELL	136
#     KLLDGS	135
#     GQGGYT	116
#     LGGFVY	103
#     HVYDLT	84
#     VHDKNV	76
#     IVRLEN	68
# Time for index table init: 0h 0m 1s 492ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 136
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 62469
# Target db start 1 to 62469
# [=================================================================] 62.47K 5s 427ms
#
# 19.568138 k-mers per position
# 3546 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 15 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 208ms
# Time for processing: 0h 0m 7s 502ms
# align tmp/6254332096599620672/input_step1 tmp/6254332096599620672/input_step1 tmp/6254332096599620672/pref_step1 tmp/6254332096599620672/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 62469 type: Aminoacid
# Target database size: 62469 type: Aminoacid
# Calculation of alignments
# [=================================================================] 62.47K 35s 613ms
# Time for merging to aln_step1: 0h 0m 0s 21ms
# 786913 alignments calculated
# 161894 sequence pairs passed the thresholds (0.205733 of overall calculated)
# 2.591589 hits per query sequence
# Time for processing: 0h 0m 35s 905ms
# clust tmp/6254332096599620672/input_step1 tmp/6254332096599620672/aln_step1 tmp/6254332096599620672/clu_step1 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 14ms
#
# Size of the sequence database: 62469
# Size of the alignment database: 62469
# Number of clusters: 43236
#
# Writing results 0h 0m 0s 11ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 121ms
# createsubdb tmp/6254332096599620672/clu_step1 tmp/6254332096599620672/input_step1 tmp/6254332096599620672/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 51ms
# prefilter tmp/6254332096599620672/input_step2 tmp/6254332096599620672/input_step2 tmp/6254332096599620672/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 5 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 43236 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 43236 type: Aminoacid
# Index table k-mer threshold: 118 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 43.24K 0s 420ms
# Index table: Masked residues: 760587
# Index table: fill
# [=================================================================] 43.24K 0s 501ms
# Index statistics
# Entries:          22300983
# DB size:          615 MB
# Avg k-mer size:   0.348453
# Top 10 k-mers
#     AAAAAA	194
#     SFRLYG	182
#     AYQGKT	178
#     YRSLLL	148
#     QTSKTM	133
#     SSSSSS	110
#     AAAAAL	103
#     VPRSTR	96
#     KLLDGS	92
#     GQGGYT	91
# Time for index table init: 0h 0m 1s 215ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 118
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 43236
# Target db start 1 to 43236
# [=================================================================] 43.24K 17s 745ms
#
# 145.913965 k-mers per position
# 23101 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 19 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 39ms
# Time for processing: 0h 0m 19s 318ms
# ...
# Size of the alignment database: 190102
# Number of clusters: 104262
#
# Writing results 0h 0m 0s 29ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 80ms
# mergeclusters process/process_redundant_db tmp/16526474843887299237/clu_redundancy tmp/16526474843887299237/linclust/6893248161584287490/pre_clust tmp/16526474843887299237/linclust/6893248161584287490/clust --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 190.10K 0s 18ms
# Clustering step 2
# [=================================================================] 104.26K 0s 34ms
# Write merged clustering
# [=================================================================] 279.08K 0s 57ms
# Time for merging to clu_redundancy: 0h 0m 0s 35ms
# Time for processing: 0h 0m 0s 144ms
# createsubdb tmp/16526474843887299237/clu_redundancy process/process_redundant_db tmp/16526474843887299237/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 44ms
# prefilter tmp/16526474843887299237/input_step_redundancy tmp/16526474843887299237/input_step_redundancy tmp/16526474843887299237/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 104262 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 104262 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 104.26K 0s 794ms
# Index table: Masked residues: 1185923
# Index table: fill
# [=================================================================] 104.26K 0s 559ms
# Index statistics
# Entries:          22555911
# DB size:          617 MB
# Avg k-mer size:   0.352436
# Top 10 k-mers
#     FAGTGK	750
#     AYQGKT	703
#     GQGGYT	304
#     YGTSTY	276
#     HVYDLT	195
#     HIYDLT	177
#     LGGFVY	171
#     NTFNLQ	140
#     PGGTAR	137
#     EKDWGV	133
# Time for index table init: 0h 0m 1s 661ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 104262
# Target db start 1 to 104262
# [=================================================================] 104.26K 1s 784ms
#
# 2.026928 k-mers per position
# 795 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 10 sequences passed prefiltering per query sequence
# 9 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 33ms
# Time for processing: 0h 0m 3s 851ms
# align tmp/16526474843887299237/input_step_redundancy tmp/16526474843887299237/input_step_redundancy tmp/16526474843887299237/pref_step0 tmp/16526474843887299237/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 104262 type: Aminoacid
# Target database size: 104262 type: Aminoacid
# Calculation of alignments
# [=================================================================] 104.26K 1m 34s 591ms
# Time for merging to aln_step0: 0h 0m 0s 229ms
# 982420 alignments calculated
# 583679 sequence pairs passed the thresholds (0.594124 of overall calculated)
# 5.598195 hits per query sequence
# Time for processing: 0h 1m 34s 940ms
# clust tmp/16526474843887299237/input_step_redundancy tmp/16526474843887299237/aln_step0 tmp/16526474843887299237/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 273ms
#
# Size of the sequence database: 104262
# Size of the alignment database: 104262
# Number of clusters: 52791
#
# Writing results 0h 0m 0s 14ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 525ms
# createsubdb tmp/16526474843887299237/clu_step0 tmp/16526474843887299237/input_step_redundancy tmp/16526474843887299237/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 22ms
# prefilter tmp/16526474843887299237/input_step1 tmp/16526474843887299237/input_step1 tmp/16526474843887299237/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 3 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 52791 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 52791 type: Aminoacid
# Index table k-mer threshold: 136 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 52.79K 0s 481ms
# Index table: Masked residues: 765478
# Index table: fill
# [=================================================================] 52.79K 0s 498ms
# Index statistics
# Entries:          24758851
# DB size:          629 MB
# Avg k-mer size:   0.386857
# Top 10 k-mers
#     FAGTGK	282
#     AYQGKT	269
#     QTSKTM	218
#     VPRSTR	152
#     KLLDGS	139
#     GQGGYT	134
#     GLNGCY	121
#     YGTSTY	117
#     LGGFVY	84
#     LASRKT	68
# Time for index table init: 0h 0m 1s 322ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 136
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 52791
# Target db start 1 to 52791
# [=================================================================] 52.79K 4s 456ms
#
# 20.052189 k-mers per position
# 3378 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 15 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 38ms
# Time for processing: 0h 0m 6s 159ms
# align tmp/16526474843887299237/input_step1 tmp/16526474843887299237/input_step1 tmp/16526474843887299237/pref_step1 tmp/16526474843887299237/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 52791 type: Aminoacid
# Target database size: 52791 type: Aminoacid
# Calculation of alignments
# [=================================================================] 52.79K 33s 14ms
# Time for merging to aln_step1: 0h 0m 0s 121ms
# 666817 alignments calculated
# 143032 sequence pairs passed the thresholds (0.214500 of overall calculated)
# 2.709401 hits per query sequence
# Time for processing: 0h 0m 33s 184ms
# clust tmp/16526474843887299237/input_step1 tmp/16526474843887299237/aln_step1 tmp/16526474843887299237/clu_step1 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 9ms
#
# Size of the sequence database: 52791
# Size of the alignment database: 52791
# Number of clusters: 35835
#
# Writing results 0h 0m 0s 9ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 93ms
# createsubdb tmp/16526474843887299237/clu_step1 tmp/16526474843887299237/input_step1 tmp/16526474843887299237/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 16ms
# prefilter tmp/16526474843887299237/input_step2 tmp/16526474843887299237/input_step2 tmp/16526474843887299237/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 5 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 35835 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 35835 type: Aminoacid
# Index table k-mer threshold: 118 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 35.83K 0s 362ms
# Index table: Masked residues: 620035
# Index table: fill
# [=================================================================] 35.83K 0s 401ms
# Index statistics
# Entries:          19328955
# DB size:          598 MB
# Avg k-mer size:   0.302015
# Top 10 k-mers
#     FAGTGK	203
#     AYQGKT	201
#     QTSKTM	153
#     VPRSTR	108
#     GQGGYT	101
#     GLNGCY	91
#     YGTSTY	83
#     AAAAAS	66
#     AAAAAV	65
#     LLLLLL	58
# Time for index table init: 0h 0m 1s 78ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 118
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 35835
# Target db start 1 to 35835
# [=================================================================] 35.83K 15s 18ms
#
# 149.262353 k-mers per position
# 21501 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 19 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 44ms
# Time for processing: 0h 0m 16s 484ms
# align tmp/16526474843887299237/input_step2 tmp/16526474843887299237/input_step2 tmp/16526474843887299237/pref_step2 tmp/16526474843887299237/aln_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 35835 type: Aminoacid
# Target database size: 35835 type: Aminoacid
# Calculation of alignments
# [=================================================================] 35.83K 19s 674ms
# Time for merging to aln_step2: 0h 0m 0s 220ms
# 527415 alignments calculated
# 55482 sequence pairs passed the thresholds (0.105196 of overall calculated)
# 1.548263 hits per query sequence
# Time for processing: 0h 0m 20s 28ms
# clust tmp/16526474843887299237/input_step2 tmp/16526474843887299237/aln_step2 tmp/16526474843887299237/clu_step2 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 131ms
#
# Size of the sequence database: 35835
# Size of the alignment database: 35835
# Number of clusters: 30239
#
# Writing results 0h 0m 0s 7ms
# Time for merging to clu_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 168ms
# mergeclusters process/process_redundant_db process/process_clusters_redundant tmp/16526474843887299237/clu_redundancy tmp/16526474843887299237/clu_step0 tmp/16526474843887299237/clu_step1 tmp/16526474843887299237/clu_step2 --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 104.26K 0s 12ms
# Clustering step 2
# [=================================================================] 52.79K 0s 22ms
# Clustering step 3
# [=================================================================] 35.83K 0s 27ms
# Clustering step 4
# [=================================================================] 30.24K 0s 32ms
# Write merged clustering
# [=================================================================] 279.08K 0s 56ms
# Time for merging to process_clusters_redundant: 0h 0m 0s 11ms
# Time for processing: 0h 0m 0s 110ms
# Creating TSV files...
# createtsv function/function_redundant_db function/function_redundant_db function/function_clusters_redundant function/function_clusters_redundant.tsv
#
# MMseqs Version:                 	14.7e284
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	10
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to function_clusters_redundant.tsv: 0h 0m 0s 34ms
# Time for processing: 0h 0m 0s 90ms
# createtsv component/component_redundant_db component/component_redundant_db component/component_clusters_redundant component/component_clusters_redundant.tsv
#
# MMseqs Version:                 	14.7e284
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	10
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to component_clusters_redundant.tsv: 0h 0m 0s 16ms
# Time for processing: 0h 0m 0s 94ms
# createtsv process/process_redundant_db process/process_redundant_db process/process_clusters_redundant process/process_clusters_redundant.tsv
#
# MMseqs Version:                 	14.7e284
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	10
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to process_clusters_redundant.tsv: 0h 0m 0s 15ms
# Time for processing: 0h 0m 0s 64ms
# All tasks completed successfully.
# CompletedProcess(args=['./mmseq_cluster.sh', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_similarity_30', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_function_propagated.fasta', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_component_propagated.fasta', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_process_propagated.fasta', '0.3'], returncode=0)

# %%
subprocess.run(["./mmseq_cluster.sh", "reduced_90_similarity_10", "reduced_90_function_propagated.fasta", "reduced_90_component_propagated.fasta", "reduced_90_process_propagated.fasta", "0.1"])
# Out:
# Creating databases...
# createdb /Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_function_propagated.fasta function/function_redundant_db
#
# MMseqs Version:       	14.7e284
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [===================================
# Time for merging to function_redundant_db_h: 0h 0m 0s 64ms
# Time for merging to function_redundant_db: 0h 0m 0s 138ms
# Database type: Aminoacid
# Time for processing: 0h 0m 1s 72ms
# createdb /Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_component_propagated.fasta component/component_redundant_db
#
# MMseqs Version:       	14.7e284
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [==============================
# Time for merging to component_redundant_db_h: 0h 0m 0s 58ms
# Time for merging to component_redundant_db: 0h 0m 0s 123ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 920ms
# createdb /Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_process_propagated.fasta process/process_redundant_db
#
# MMseqs Version:       	14.7e284
# Database type         	0
# Shuffle input database	true
# Createdb mode         	0
# Write lookup file     	1
# Offset of numeric ids 	0
# Compressed            	0
# Verbosity             	3
#
# Converting sequences
# [===========================
# Time for merging to process_redundant_db_h: 0h 0m 0s 55ms
# Time for merging to process_redundant_db: 0h 0m 0s 119ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 881ms
# Clustering sequences...
# Create directory tmp
# cluster function/function_redundant_db function/function_clusters_redundant tmp --min-seq-id 0.1 -c 0.5 --cov-mode 1
#
# MMseqs Version:                     	14.7e284
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.5
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	10
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.1
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 6.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 3
# linclust function/function_redundant_db tmp/4508048661228596920/clu_redundancy tmp/4508048661228596920/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher function/function_redundant_db tmp/4508048661228596920/linclust/2783909104000407252/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.1 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# kmermatcher function/function_redundant_db tmp/4508048661228596920/linclust/2783909104000407252/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.1 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# Database size: 352499 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 352.50K 0s 867ms
# Sort kmer 0h 0m 0s 147ms
# Sort by rep. sequence 0h 0m 0s 84ms
# Time for fill: 0h 0m 0s 95ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 1s 362ms
# rescorediagonal function/function_redundant_db function/function_redundant_db tmp/4508048661228596920/linclust/2783909104000407252/pref tmp/4508048661228596920/linclust/2783909104000407252/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 352.50K 0s 142ms
# Time for merging to pref_rescore1: 0h 0m 0s 280ms
# Time for processing: 0h 0m 0s 518ms
# clust function/function_redundant_db tmp/4508048661228596920/linclust/2783909104000407252/pref_rescore1 tmp/4508048661228596920/linclust/2783909104000407252/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 48ms
#
# Size of the sequence database: 352499
# Size of the alignment database: 352499
# Number of clusters: 240467
#
# Writing results 0h 0m 0s 62ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 149ms
# createsubdb tmp/4508048661228596920/linclust/2783909104000407252/order_redundancy function/function_redundant_db tmp/4508048661228596920/linclust/2783909104000407252/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 83ms
# createsubdb tmp/4508048661228596920/linclust/2783909104000407252/order_redundancy tmp/4508048661228596920/linclust/2783909104000407252/pref tmp/4508048661228596920/linclust/2783909104000407252/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 90ms
# filterdb tmp/4508048661228596920/linclust/2783909104000407252/pref_filter1 tmp/4508048661228596920/linclust/2783909104000407252/pref_filter2 --filter-file tmp/4508048661228596920/linclust/2783909104000407252/order_redundancy --threads 10 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 240.47K 0s 68ms
# Time for merging to pref_filter2: 0h 0m 0s 137ms
# Time for processing: 0h 0m 0s 308ms
# rescorediagonal tmp/4508048661228596920/linclust/2783909104000407252/input_step_redundancy tmp/4508048661228596920/linclust/2783909104000407252/input_step_redundancy tmp/4508048661228596920/linclust/2783909104000407252/pref_filter2 tmp/4508048661228596920/linclust/2783909104000407252/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# Can not find any score per column for coverage 0.500000 and sequence identity 0.100000. No hit will be filtered.
# [=================================================================] 240.47K 0s 130ms
# Time for merging to pref_rescore2: 0h 0m 0s 133ms
# Time for processing: 0h 0m 0s 375ms
# align tmp/4508048661228596920/linclust/2783909104000407252/input_step_redundancy tmp/4508048661228596920/linclust/2783909104000407252/input_step_redundancy tmp/4508048661228596920/linclust/2783909104000407252/pref_rescore2 tmp/4508048661228596920/linclust/2783909104000407252/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 240467 type: Aminoacid
# Target database size: 240467 type: Aminoacid
# Calculation of alignments
# [=================================================================] 240.47K 39s 870ms
# Time for merging to aln: 0h 0m 0s 266ms
# 699781 alignments calculated
# 549536 sequence pairs passed the thresholds (0.785297 of overall calculated)
# 2.285286 hits per query sequence
# Time for processing: 0h 0m 40s 282ms
# clust tmp/4508048661228596920/linclust/2783909104000407252/input_step_redundancy tmp/4508048661228596920/linclust/2783909104000407252/aln tmp/4508048661228596920/linclust/2783909104000407252/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 108ms
#
# Size of the sequence database: 240467
# Size of the alignment database: 240467
# Number of clusters: 125597
#
# Writing results 0h 0m 0s 34ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 204ms
# mergeclusters function/function_redundant_db tmp/4508048661228596920/clu_redundancy tmp/4508048661228596920/linclust/2783909104000407252/pre_clust tmp/4508048661228596920/linclust/2783909104000407252/clust --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 240.47K 0s 29ms
# Clustering step 2
# [=================================================================] 125.60K 0s 97ms
# Write merged clustering
# [=================================================================] 352.50K 0s 131ms
# Time for merging to clu_redundancy: 0h 0m 0s 99ms
# Time for processing: 0h 0m 0s 326ms
# createsubdb tmp/4508048661228596920/clu_redundancy function/function_redundant_db tmp/4508048661228596920/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 55ms
# prefilter tmp/4508048661228596920/input_step_redundancy tmp/4508048661228596920/input_step_redundancy tmp/4508048661228596920/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 125597 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 125597 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 125.60K 0s 959ms
# Index table: Masked residues: 1446711
# Index table: fill
# [=================================================================] 125.60K 0s 791ms
# Index statistics
# Entries:          27640375
# DB size:          646 MB
# Avg k-mer size:   0.431881
# Top 10 k-mers
#     FAGTGK	714
#     AYQGKT	654
#     HRLPIL	346
#     GQGGHT	306
#     LGGFVY	299
#     HRIPIL	251
#     IPRSTR	246
#     YGTSTY	246
#     GQGGFT	211
#     VHDKNV	210
# Time for index table init: 0h 0m 2s 44ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 125597
# Target db start 1 to 125597
# [=================================================================] 125.60K 2s 386ms
#
# 2.101738 k-mers per position
# 945 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 11 sequences passed prefiltering per query sequence
# 10 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 43ms
# Time for processing: 0h 0m 4s 777ms
# align tmp/4508048661228596920/input_step_redundancy tmp/4508048661228596920/input_step_redundancy tmp/4508048661228596920/pref_step0 tmp/4508048661228596920/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 125597 type: Aminoacid
# Target database size: 125597 type: Aminoacid
# Calculation of alignments
# [=================================================================] 125.60K 1m 45s 671ms
# Time for merging to aln_step0: 0h 0m 0s 263ms
# 1254803 alignments calculated
# 849941 sequence pairs passed the thresholds (0.677350 of overall calculated)
# 6.767208 hits per query sequence
# Time for processing: 0h 1m 46s 28ms
# clust tmp/4508048661228596920/input_step_redundancy tmp/4508048661228596920/aln_step0 tmp/4508048661228596920/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 262ms
#
# Size of the sequence database: 125597
# Size of the alignment database: 125597
# Number of clusters: 58417
#
# Writing results 0h 0m 0s 17ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 520ms
# createsubdb tmp/4508048661228596920/clu_step0 tmp/4508048661228596920/input_step_redundancy tmp/4508048661228596920/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 27ms
# prefilter tmp/4508048661228596920/input_step1 tmp/4508048661228596920/input_step1 tmp/4508048661228596920/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 3.5 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 58417 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 58417 type: Aminoacid
# Index table k-mer threshold: 131 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 58.42K 0s 566ms
# Index table: Masked residues: 926134
# Index table: fill
# [=================================================================] 58.42K 0s 592ms
# Index statistics
# Entries:          28827102
# DB size:          653 MB
# Avg k-mer size:   0.450423
# Top 10 k-mers
#     FAGTGK	227
#     AYQGKT	222
#     QTSKTM	170
#     KLRLSL	133
#     GPGGTL	128
#     VPRSTR	121
#     KLLDGS	114
#     LGGFVY	110
#     SKTLDS	94
#     VHDKNV	94
# Time for index table init: 0h 0m 1s 509ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 131
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 58417
# Target db start 1 to 58417
# [=================================================================] 58.42K 8s 284ms
#
# 36.740094 k-mers per position
# 7072 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 18 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 29ms
# Time for processing: 0h 0m 10s 105ms
# align tmp/4508048661228596920/input_step1 tmp/4508048661228596920/input_step1 tmp/4508048661228596920/pref_step1 tmp/4508048661228596920/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 58417 type: Aminoacid
# Target database size: 58417 type: Aminoacid
# Calculation of alignments
# [=================================================================] 58.42K 36s 928ms
# Time for merging to aln_step1: 0h 0m 0s 211ms
# 830220 alignments calculated
# 241064 sequence pairs passed the thresholds (0.290362 of overall calculated)
# 4.126607 hits per query sequence
# Time for processing: 0h 0m 37s 240ms
# clust tmp/4508048661228596920/input_step1 tmp/4508048661228596920/aln_step1 tmp/4508048661228596920/clu_step1 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 218ms
#
# Size of the sequence database: 58417
# Size of the alignment database: 58417
# Number of clusters: 33583
#
# Writing results 0h 0m 0s 9ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 410ms
# createsubdb tmp/4508048661228596920/clu_step1 tmp/4508048661228596920/input_step1 tmp/4508048661228596920/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 18ms
# prefilter tmp/4508048661228596920/input_step2 tmp/4508048661228596920/input_step2 tmp/4508048661228596920/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 6 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 33583 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 33583 type: Aminoacid
# Index table k-mer threshold: 109 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 33.58K 0s 409ms
# Index table: Masked residues: 702668
# Index table: fill
# [=================================================================] 33.58K 0s 424ms
# Index statistics
# Entries:          18863990
# DB size:          596 MB
# Avg k-mer size:   0.294750
# Top 10 k-mers
#     FAGTGK	174
#     AYQGKT	168
#     YRSLLL	138
#     QTSKTM	124
#     KLRLSL	101
#     SSSSSS	96
#     GQGGYT	86
#     GQGGHT	72
#     YGTSTY	68
#     AAAAAV	63
# Time for index table init: 0h 0m 1s 117ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 109
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 33583
# Target db start 1 to 33583
# [=================================================================] 33.58K 36s 804ms
#
# 388.003728 k-mers per position
# 61331 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 19 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 168ms
# Time for processing: 0h 0m 38s 386ms
# align tmp/4508048661228596920/input_step2 tmp/4508048661228596920/input_step2 tmp/4508048661228596920/pref_step2 tmp/4508048661228596920/aln_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 33583 type: Aminoacid
# Target database size: 33583 type: Aminoacid
# Calculation of alignments
# [=================================================================] 33.58K 15s 623ms
# Time for merging to aln_step2: 0h 0m 0s 237ms
# 498957 alignments calculated
# 72418 sequence pairs passed the thresholds (0.145139 of overall calculated)
# 2.156389 hits per query sequence
# Time for processing: 0h 0m 15s 971ms
# clust tmp/4508048661228596920/input_step2 tmp/4508048661228596920/aln_step2 tmp/4508048661228596920/clu_step2 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 308ms
#
# Size of the sequence database: 33583
# Size of the alignment database: 33583
# Number of clusters: 25374
#
# Writing results 0h 0m 0s 6ms
# Time for merging to clu_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 545ms
# mergeclusters function/function_redundant_db function/function_clusters_redundant tmp/4508048661228596920/clu_redundancy tmp/4508048661228596920/clu_step0 tmp/4508048661228596920/clu_step1 tmp/4508048661228596920/clu_step2 --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 125.60K 0s 22ms
# Clustering step 2
# [=================================================================] 58.42K 0s 119ms
# Clustering step 3
# [=================================================================] 33.58K 0s 202ms
# Clustering step 4
# [=================================================================] 25.37K 0s 301ms
# Write merged clustering
# [=================================================================] 352.50K 0s 364ms
# Time for merging to function_clusters_redundant: 0h 0m 0s 203ms
# Time for processing: 0h 0m 0s 830ms
# cluster component/component_redundant_db component/component_clusters_redundant tmp --min-seq-id 0.1 -c 0.5 --cov-mode 1
#
# MMseqs Version:                     	14.7e284
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.5
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	10
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.1
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 6.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 3
# linclust component/component_redundant_db tmp/14807645540069108862/clu_redundancy tmp/14807645540069108862/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher component/component_redundant_db tmp/14807645540069108862/linclust/11716136117351556594/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.1 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# kmermatcher component/component_redundant_db tmp/14807645540069108862/linclust/11716136117351556594/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.1 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 10 --compressed 0 -v 3
#
# Database size: 304622 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 304.62K 0s 605ms
# Sort kmer 0h 0m 0s 323ms
# Sort by rep. sequence 0h 0m 0s 222ms
# Time for fill: 0h 0m 0s 78ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 1s 403ms
# rescorediagonal component/component_redundant_db component/component_redundant_db tmp/14807645540069108862/linclust/11716136117351556594/pref tmp/14807645540069108862/linclust/11716136117351556594/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# [=================================================================] 304.62K 0s 111ms
# Time for merging to pref_rescore1: 0h 0m 0s 150ms
# Time for processing: 0h 0m 0s 436ms
# clust component/component_redundant_db tmp/14807645540069108862/linclust/11716136117351556594/pref_rescore1 tmp/14807645540069108862/linclust/11716136117351556594/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 45ms
#
# Size of the sequence database: 304622
# Size of the alignment database: 304622
# Number of clusters: 210629
#
# Writing results 0h 0m 0s 55ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 138ms
# createsubdb tmp/14807645540069108862/linclust/11716136117351556594/order_redundancy component/component_redundant_db tmp/14807645540069108862/linclust/11716136117351556594/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 73ms
# createsubdb tmp/14807645540069108862/linclust/11716136117351556594/order_redundancy tmp/14807645540069108862/linclust/11716136117351556594/pref tmp/14807645540069108862/linclust/11716136117351556594/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 76ms
# filterdb tmp/14807645540069108862/linclust/11716136117351556594/pref_filter1 tmp/14807645540069108862/linclust/11716136117351556594/pref_filter2 --filter-file tmp/14807645540069108862/linclust/11716136117351556594/order_redundancy --threads 10 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 210.63K 0s 55ms
# Time for merging to pref_filter2: 0h 0m 0s 140ms
# Time for processing: 0h 0m 0s 368ms
# rescorediagonal tmp/14807645540069108862/linclust/11716136117351556594/input_step_redundancy tmp/14807645540069108862/linclust/11716136117351556594/input_step_redundancy tmp/14807645540069108862/linclust/11716136117351556594/pref_filter2 tmp/14807645540069108862/linclust/11716136117351556594/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 10 --compressed 0 -v 3
#
# Can not find any score per column for coverage 0.500000 and sequence identity 0.100000. No hit will be filtered.
# [=================================================================] 210.63K 0s 102ms
# Time for merging to pref_rescore2: 0h 0m 0s 120ms
# Time for processing: 0h 0m 0s 326ms
# align tmp/14807645540069108862/linclust/11716136117351556594/input_step_redundancy tmp/14807645540069108862/linclust/11716136117351556594/input_step_redundancy tmp/14807645540069108862/linclust/11716136117351556594/pref_rescore2 tmp/14807645540069108862/linclust/11716136117351556594/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 210629 type: Aminoacid
# Target database size: 210629 type: Aminoacid
# Calculation of alignments
# [=================================================================] 210.63K 30s 941ms
# Time for merging to aln: 0h 0m 0s 125ms
# 580810 alignments calculated
# 455755 sequence pairs passed the thresholds (0.784689 of overall calculated)
# 2.163781 hits per query sequence
# Time for processing: 0h 0m 31s 292ms
# clust tmp/14807645540069108862/linclust/11716136117351556594/input_step_redundancy tmp/14807645540069108862/linclust/11716136117351556594/aln tmp/14807645540069108862/linclust/11716136117351556594/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 33ms
#
# Size of the sequence database: 210629
# Size of the alignment database: 210629
# Number of clusters: 115899
#
# Writing results 0h 0m 0s 31ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 97ms
# mergeclusters component/component_redundant_db tmp/14807645540069108862/clu_redundancy tmp/14807645540069108862/linclust/11716136117351556594/pre_clust tmp/14807645540069108862/linclust/11716136117351556594/clust --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 210.63K 0s 19ms
# Clustering step 2
# [=================================================================] 115.90K 0s 40ms
# Write merged clustering
# [=================================================================] 304.62K 0s 64ms
# Time for merging to clu_redundancy: 0h 0m 0s 108ms
# Time for processing: 0h 0m 0s 244ms
# createsubdb tmp/14807645540069108862/clu_redundancy component/component_redundant_db tmp/14807645540069108862/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 50ms
# prefilter tmp/14807645540069108862/input_step_redundancy tmp/14807645540069108862/input_step_redundancy tmp/14807645540069108862/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 115899 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 115899 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 115.90K 0s 805ms
# Index table: Masked residues: 1349809
# Index table: fill
# [=================================================================] 115.90K 0s 572ms
# Index statistics
# Entries:          24093583
# DB size:          626 MB
# Avg k-mer size:   0.376462
# Top 10 k-mers
#     FAGTGK	602
#     AYQGKT	584
#     VHDKNI	300
#     GQGGHT	259
#     GQGGYT	242
#     IPRSTR	227
#     YGTSTY	226
#     LGGFVY	190
#     HHPICV	153
#     PQLWEW	143
# Time for index table init: 0h 0m 1s 667ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 115899
# Target db start 1 to 115899
# [=================================================================] 115.90K 1s 951ms
#
# 2.049775 k-mers per position
# 794 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 9 sequences passed prefiltering per query sequence
# 8 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 40ms
# Time for processing: 0h 0m 3s 961ms
# align tmp/14807645540069108862/input_step_redundancy tmp/14807645540069108862/input_step_redundancy tmp/14807645540069108862/pref_step0 tmp/14807645540069108862/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 115899 type: Aminoacid
# Target database size: 115899 type: Aminoacid
# Calculation of alignments
# [=================================================================] 115.90K 1m 24s 87ms
# Time for merging to aln_step0: 0h 0m 0s 219ms
# 1022176 alignments calculated
# 703355 sequence pairs passed the thresholds (0.688096 of overall calculated)
# 6.068689 hits per query sequence
# Time for processing: 0h 1m 24s 455ms
# clust tmp/14807645540069108862/input_step_redundancy tmp/14807645540069108862/aln_step0 tmp/14807645540069108862/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 298ms
#
# Size of the sequence database: 115899
# Size of the alignment database: 115899
# Number of clusters: 57209
#
# Writing results 0h 0m 0s 16ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 556ms
# createsubdb tmp/14807645540069108862/clu_step0 tmp/14807645540069108862/input_step_redundancy tmp/14807645540069108862/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 25ms
# prefilter tmp/14807645540069108862/input_step1 tmp/14807645540069108862/input_step1 tmp/14807645540069108862/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 3.5 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 57209 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 57209 type: Aminoacid
# Index table k-mer threshold: 131 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 57.21K 0s 510ms
# Index table: Masked residues: 858739
# Index table: fill
# [=================================================================] 57.21K 0s 613ms
# Index statistics
# Entries:          26585862
# DB size:          640 MB
# Avg k-mer size:   0.415404
# Top 10 k-mers
#     FAGTGK	191
#     AYQGKT	191
#     QTSKTM	134
#     KLLDGS	112
#     GPGGTL	104
#     AAAAAP	93
#     GQGGYT	90
#     GQGGHT	79
#     YGTSTY	79
#     LGGFVY	78
# Time for index table init: 0h 0m 1s 445ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 131
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 57209
# Target db start 1 to 57209
# [=================================================================] 57.21K 7s 270ms
#
# 34.706102 k-mers per position
# 5784 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 17 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 212ms
# Time for processing: 0h 0m 9s 310ms
# align tmp/14807645540069108862/input_step1 tmp/14807645540069108862/input_step1 tmp/14807645540069108862/pref_step1 tmp/14807645540069108862/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 57209 type: Aminoacid
# Target database size: 57209 type: Aminoacid
# Calculation of alignments
# [=================================================================] 57.21K 30s 755ms
# Time for merging to aln_step1: 0h 0m 0s 204ms
# 773872 alignments calculated
# 216641 sequence pairs passed the thresholds (0.279944 of overall calculated)
# 3.786834 hits per query sequence
# Time for processing: 0h 0m 31s 71ms
# clust tmp/14807645540069108862/input_step1 tmp/14807645540069108862/aln_step1 tmp/14807645540069108862/clu_step1 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 269ms
#
# Size of the sequence database: 57209
# Size of the alignment database: 57209
# Number of clusters: 33911
#
# Writing results 0h 0m 0s 11ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 494ms
# createsubdb tmp/14807645540069108862/clu_step1 tmp/14807645540069108862/input_step1 tmp/14807645540069108862/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 16ms
# prefilter tmp/14807645540069108862/input_step2 tmp/14807645540069108862/input_step2 tmp/14807645540069108862/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 6 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 33911 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 33911 type: Aminoacid
# Index table k-mer threshold: 109 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 33.91K 0s 367ms
# Index table: Masked residues: 653344
# Index table: fill
# [=================================================================] 33.91K 0s 387ms
# Index statistics
# Entries:          17818250
# DB size:          590 MB
# Avg k-mer size:   0.278410
# Top 10 k-mers
#     AAAAAA	157
#     SFRLYG	147
#     AYQGKT	144
#     YRSLLL	118
#     QTSKTM	103
#     SSSSSS	99
#     KLLDGS	78
#     GQGGYT	72
#     YGTSTY	64
#     RDKTLQ	61
# Time for index table init: 0h 0m 1s 85ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 109
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 33911
# Target db start 1 to 33911
# [=================================================================] 33.91K 34s 845ms
#
# 372.219593 k-mers per position
# 51711 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 19 sequences passed prefiltering per query sequence
# ...
# Total time: 0h 0m 0s 25ms
#
# Size of the sequence database: 190102
# Size of the alignment database: 190102
# Number of clusters: 101520
#
# Writing results 0h 0m 0s 28ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 76ms
# mergeclusters process/process_redundant_db tmp/9968614989288362083/clu_redundancy tmp/9968614989288362083/linclust/17894407855695214801/pre_clust tmp/9968614989288362083/linclust/17894407855695214801/clust --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 190.10K 0s 18ms
# Clustering step 2
# [=================================================================] 101.52K 0s 32ms
# Write merged clustering
# [=================================================================] 279.08K 0s 54ms
# Time for merging to clu_redundancy: 0h 0m 0s 104ms
# Time for processing: 0h 0m 0s 226ms
# createsubdb tmp/9968614989288362083/clu_redundancy process/process_redundant_db tmp/9968614989288362083/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 44ms
# prefilter tmp/9968614989288362083/input_step_redundancy tmp/9968614989288362083/input_step_redundancy tmp/9968614989288362083/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 101520 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 101520 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 101.52K 0s 712ms
# Index table: Masked residues: 1162670
# Index table: fill
# [=================================================================] 101.52K 0s 535ms
# Index statistics
# Entries:          21859836
# DB size:          613 MB
# Avg k-mer size:   0.341560
# Top 10 k-mers
#     FAGTGK	710
#     AYQGKT	653
#     GQGGYT	268
#     YGTSTY	248
#     HVYDLT	182
#     HIYDLT	169
#     LGGFVY	158
#     SGTTGP	136
#     NTFNLQ	136
#     PGGTAR	132
# Time for index table init: 0h 0m 1s 557ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 101520
# Target db start 1 to 101520
# [=================================================================] 101.52K 1s 758ms
#
# 2.027772 k-mers per position
# 769 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 10 sequences passed prefiltering per query sequence
# 9 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 31ms
# Time for processing: 0h 0m 3s 644ms
# align tmp/9968614989288362083/input_step_redundancy tmp/9968614989288362083/input_step_redundancy tmp/9968614989288362083/pref_step0 tmp/9968614989288362083/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 101520 type: Aminoacid
# Target database size: 101520 type: Aminoacid
# Calculation of alignments
# [=================================================================] 101.52K 1m 23s 101ms
# Time for merging to aln_step0: 0h 0m 0s 216ms
# 934590 alignments calculated
# 659192 sequence pairs passed the thresholds (0.705327 of overall calculated)
# 6.493223 hits per query sequence
# Time for processing: 0h 1m 23s 449ms
# clust tmp/9968614989288362083/input_step_redundancy tmp/9968614989288362083/aln_step0 tmp/9968614989288362083/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 50ms
#
# Size of the sequence database: 101520
# Size of the alignment database: 101520
# Number of clusters: 48238
#
# Writing results 0h 0m 0s 13ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 113ms
# createsubdb tmp/9968614989288362083/clu_step0 tmp/9968614989288362083/input_step_redundancy tmp/9968614989288362083/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 21ms
# prefilter tmp/9968614989288362083/input_step1 tmp/9968614989288362083/input_step1 tmp/9968614989288362083/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 3.5 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 48238 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 48238 type: Aminoacid
# Index table k-mer threshold: 131 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 48.24K 0s 459ms
# Index table: Masked residues: 715986
# Index table: fill
# [=================================================================] 48.24K 0s 477ms
# Index statistics
# Entries:          23319005
# DB size:          621 MB
# Avg k-mer size:   0.364359
# Top 10 k-mers
#     FAGTGK	224
#     AYQGKT	210
#     QTSKTM	172
#     VPRSTR	129
#     KLLDGS	102
#     GQGGYT	102
#     YGTSTY	90
#     LGGFVY	67
#     PGGTAR	59
#     LVCASR	59
# Time for index table init: 0h 0m 1s 216ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 131
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 48238
# Target db start 1 to 48238
# [=================================================================] 48.24K 6s 173ms
#
# 35.646166 k-mers per position
# 5485 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 17 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 33ms
# Time for processing: 0h 0m 7s 766ms
# align tmp/9968614989288362083/input_step1 tmp/9968614989288362083/input_step1 tmp/9968614989288362083/pref_step1 tmp/9968614989288362083/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 48238 type: Aminoacid
# Target database size: 48238 type: Aminoacid
# Calculation of alignments
# [=================================================================] 48.24K 28s 331ms
# Time for merging to aln_step1: 0h 0m 0s 197ms
# 656141 alignments calculated
# 188872 sequence pairs passed the thresholds (0.287853 of overall calculated)
# 3.915419 hits per query sequence
# Time for processing: 0h 0m 28s 639ms
# clust tmp/9968614989288362083/input_step1 tmp/9968614989288362083/aln_step1 tmp/9968614989288362083/clu_step1 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 33ms
#
# Size of the sequence database: 48238
# Size of the alignment database: 48238
# Number of clusters: 27968
#
# Writing results 0h 0m 0s 8ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 56ms
# createsubdb tmp/9968614989288362083/clu_step1 tmp/9968614989288362083/input_step1 tmp/9968614989288362083/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 14ms
# prefilter tmp/9968614989288362083/input_step2 tmp/9968614989288362083/input_step2 tmp/9968614989288362083/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 6 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 10 --compressed 0 -v 3
#
# Query database size: 27968 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 27968 type: Aminoacid
# Index table k-mer threshold: 109 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 27.97K 0s 297ms
# Index table: Masked residues: 527130
# Index table: fill
# [=================================================================] 27.97K 0s 327ms
# Index statistics
# Entries:          15466191
# DB size:          576 MB
# Avg k-mer size:   0.241659
# Top 10 k-mers
#     FAGTGK	168
#     AYQGKT	163
#     QTSKTM	126
#     VPRSTR	93
#     SSSSSS	92
#     GQGGYT	83
#     YGTSTY	66
#     HVYDLT	57
#     AAAAAV	55
#     VHDKNI	50
# Time for index table init: 0h 0m 0s 915ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 109
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 27968
# Target db start 1 to 27968
# [=================================================================] 27.97K 28s 389ms
#
# 381.915693 k-mers per position
# 48472 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 19 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 11ms
# Time for processing: 0h 0m 29s 590ms
# align tmp/9968614989288362083/input_step2 tmp/9968614989288362083/input_step2 tmp/9968614989288362083/pref_step2 tmp/9968614989288362083/aln_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.1 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 10 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 27968 type: Aminoacid
# Target database size: 27968 type: Aminoacid
# Calculation of alignments
# [=================================================================] 27.97K 12s 94ms
# Time for merging to aln_step2: 0h 0m 0s 57ms
# 409986 alignments calculated
# 60303 sequence pairs passed the thresholds (0.147086 of overall calculated)
# 2.156143 hits per query sequence
# Time for processing: 0h 0m 12s 260ms
# clust tmp/9968614989288362083/input_step2 tmp/9968614989288362083/aln_step2 tmp/9968614989288362083/clu_step2 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 10 --compressed 0 -v 3
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 6ms
#
# Size of the sequence database: 27968
# Size of the alignment database: 27968
# Number of clusters: 20805
#
# Writing results 0h 0m 0s 5ms
# Time for merging to clu_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 33ms
# mergeclusters process/process_redundant_db process/process_clusters_redundant tmp/9968614989288362083/clu_redundancy tmp/9968614989288362083/clu_step0 tmp/9968614989288362083/clu_step1 tmp/9968614989288362083/clu_step2 --threads 10 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 101.52K 0s 13ms
# Clustering step 2
# [=================================================================] 48.24K 0s 22ms
# Clustering step 3
# [=================================================================] 27.97K 0s 28ms
# Clustering step 4
# [=================================================================] 20.81K 0s 30ms
# Write merged clustering
# [=================================================================] 279.08K 0s 51ms
# Time for merging to process_clusters_redundant: 0h 0m 0s 57ms
# Time for processing: 0h 0m 0s 198ms
# Creating TSV files...
# createtsv function/function_redundant_db function/function_redundant_db function/function_clusters_redundant function/function_clusters_redundant.tsv
#
# MMseqs Version:                 	14.7e284
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	10
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to function_clusters_redundant.tsv: 0h 0m 0s 37ms
# Time for processing: 0h 0m 0s 163ms
# createtsv component/component_redundant_db component/component_redundant_db component/component_clusters_redundant component/component_clusters_redundant.tsv
#
# MMseqs Version:                 	14.7e284
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	10
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to component_clusters_redundant.tsv: 0h 0m 0s 19ms
# Time for processing: 0h 0m 0s 97ms
# createtsv process/process_redundant_db process/process_redundant_db process/process_clusters_redundant process/process_clusters_redundant.tsv
#
# MMseqs Version:                 	14.7e284
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	10
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to process_clusters_redundant.tsv: 0h 0m 0s 92ms
# Time for processing: 0h 0m 0s 162ms
# All tasks completed successfully.
# CompletedProcess(args=['./mmseq_cluster.sh', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_similarity_10', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_function_propagated.fasta', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_component_propagated.fasta', '/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_process_propagated.fasta', '0.1'], returncode=0)

# %% [markdown]
# # Train, dev, test split

# %%
function_mmseq_out = pd.read_csv("reduced_90_similarity_30/function/function_clusters_redundant.tsv", sep='\t', header=None)
function_mmseq_out.columns = ['Cluster_2', 'Entry']

component_mmseq_out = pd.read_csv("reduced_90_similarity_30/component/component_clusters_redundant.tsv", sep='\t', header=None)
component_mmseq_out.columns = ['Cluster_2', 'Entry']

process_mmseq_out = pd.read_csv("reduced_90_similarity_30/process/process_clusters_redundant.tsv", sep='\t', header=None)
process_mmseq_out.columns = ['Cluster_2', 'Entry']

print("There are {} clusters in the function dataset.".format(function_mmseq_out['Cluster_2'].nunique()))
print("There are {} clusters in the component dataset.".format(component_mmseq_out['Cluster_2'].nunique()))
print("There are {} clusters in the process dataset.".format(process_mmseq_out['Cluster_2'].nunique()))

assert len(function_mmseq_out) == len(total_SAR_function_GO)
assert len(component_mmseq_out) == len(total_SAR_component_GO)
assert len(process_mmseq_out) == len(total_SAR_process_GO)
# Out:
# There are 36398 clusters in the function dataset.
# There are 36571 clusters in the component dataset.
# There are 30239 clusters in the process dataset.

# %%
#merge with the original datasets
function_merged = pd.merge(function_mmseq_out, total_SAR_function_GO, on='Entry')
component_merged = pd.merge(component_mmseq_out, total_SAR_component_GO, on='Entry')
process_merged = pd.merge(process_mmseq_out, total_SAR_process_GO, on='Entry')

assert len(function_merged) == len(function_mmseq_out)
assert len(component_merged) == len(component_mmseq_out)
assert len(process_merged) == len(process_mmseq_out)

# %%
#read in RNA_associated_proteins_UniProtIDs.pkl
RNA_associated_proteins = pd.read_pickle("/RNA_associated_proteins_UniProtIDs.pkl")

# %%
seqs_to_remove = RNA_associated_proteins

#print the original shapes 
print("Original shapes:")
print("Function:", function_merged.shape)
print("Component:", component_merged.shape)
print("Process:", process_merged.shape)

function_merged = function_merged[~function_merged['Entry'].isin(seqs_to_remove)]
component_merged = component_merged[~component_merged['Entry'].isin(seqs_to_remove)]
process_merged = process_merged[~process_merged['Entry'].isin(seqs_to_remove)]

print("After removing RNA associated proteins:")
print("Function:", function_merged.shape)
print("Component:", component_merged.shape)
print("Process:", process_merged.shape)
# Out:
# Original shapes:
# Function: (352499, 14)
# Component: (304622, 14)
# Process: (279080, 14)
# After removing RNA associated proteins:
# Function: (352461, 14)
# Component: (304567, 14)
# Process: (279033, 14)

# %%
def prepare_data_and_split(go_terms_df, clusters_col='NA', terms_col='NA'):
    # Mapping clusters to GO terms and vice versa
    cluster_to_terms = defaultdict(list)
    term_to_clusters = defaultdict(set)

    for _, row in tqdm(go_terms_df.iterrows(), total=go_terms_df.shape[0], desc="Processing rows"):
        cluster, terms = row[clusters_col], row[terms_col]
        cluster_to_terms[cluster].extend(terms)
        for term in terms:
            term_to_clusters[term].add(cluster)

    # Identifying unique and multi-occurrence clusters
    print("Identifying unique and multi-occurrence clusters")

    unique_clusters = {cluster for cluster, terms in cluster_to_terms.items()
                       if all(len(term_to_clusters[term]) == 1 for term in terms)}
    multi_clusters = set(cluster_to_terms.keys()) - unique_clusters

    # Binarizing the GO terms
    mlb = MultiLabelBinarizer()
    all_terms = [terms for terms in cluster_to_terms.values()]
    mlb.fit(all_terms)

    # ShuffleSplit for training, validation, and test sets from multi occurrence clusters
    print("ShuffleSplit for training, validation, and test sets from multi occurrence clusters")
    ss = ShuffleSplit(n_splits=1, test_size=0.1, random_state=38)
    multi_clusters_list = list(multi_clusters)
    train_val_idx, test_idx = next(ss.split(multi_clusters_list))

    train_val_clusters = [multi_clusters_list[i] for i in train_val_idx]
    ss_train_val = ShuffleSplit(n_splits=1, test_size=0.1, random_state=38)
    train_idx, val_idx = next(ss_train_val.split(train_val_clusters))

    train_clusters = [train_val_clusters[i] for i in train_idx] + list(unique_clusters)
    val_clusters = [train_val_clusters[i] for i in val_idx]
    test_clusters = [multi_clusters_list[i] for i in test_idx]

    # Initial data extraction
    print("Extracting rows for each set")
    train_df = go_terms_df[go_terms_df[clusters_col].isin(train_clusters)]
    val_df = go_terms_df[go_terms_df[clusters_col].isin(val_clusters)]
    test_df = go_terms_df[go_terms_df[clusters_col].isin(test_clusters)]

    # Check and adjust for missing terms in training set
    train_terms = set(sum(train_df[terms_col].tolist(), []))
    val_terms = set(sum(val_df[terms_col].tolist(), []))
    test_terms = set(sum(test_df[terms_col].tolist(), []))

    missing_val_terms = val_terms - train_terms
    missing_test_terms = test_terms - train_terms

    # Move clusters with missing terms from val/test to train
    print("Moving clusters with missing terms from validation/test to training")
    if missing_val_terms:
        val_clusters_to_move = [cluster for cluster in val_clusters if any(term in missing_val_terms for term in cluster_to_terms[cluster])]
        train_clusters.extend(val_clusters_to_move)
        val_clusters = list(set(val_clusters) - set(val_clusters_to_move))

    if missing_test_terms:
        test_clusters_to_move = [cluster for cluster in test_clusters if any(term in missing_test_terms for term in cluster_to_terms[cluster])]
        train_clusters.extend(test_clusters_to_move)
        test_clusters = list(set(test_clusters) - set(test_clusters_to_move))

    # Re-extract dataframes after adjustment
    train_df = go_terms_df[go_terms_df[clusters_col].isin(train_clusters)]
    val_df = go_terms_df[go_terms_df[clusters_col].isin(val_clusters)]
    test_df = go_terms_df[go_terms_df[clusters_col].isin(test_clusters)]

    #recalculate missing val/test terms
    train_terms = set(sum(train_df[terms_col].tolist(), []))
    val_terms = set(sum(val_df[terms_col].tolist(), []))
    test_terms = set(sum(test_df[terms_col].tolist(), []))

    missing_val_terms = val_terms - train_terms
    missing_test_terms = test_terms - train_terms

    print("Validation terms not in training:", missing_val_terms)
    print("Test terms not in training:", missing_test_terms)

    ###### 
    propagated_terms_col = 'Raw propagated GO terms'  # Replace with the actual column name if different

    min_training_instances = 50 
    # Filter out terms from the training set that don't meet the minimum instance threshold
    train_terms_counter = Counter([term for terms in train_df[propagated_terms_col].tolist() for term in terms])
    terms_below_threshold = {term for term, count in train_terms_counter.items() if count < min_training_instances}

    print(f"Terms below threshold ({min_training_instances} occurrences):", terms_below_threshold)

    if terms_below_threshold:
        print(f"Filtering out {len(terms_below_threshold)} terms from the training set.")
        train_df[propagated_terms_col] = train_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
        train_df = train_df[train_df[propagated_terms_col].apply(len) > 0]  # Remove rows with no terms after filtering

    # Optionally, filter validation and test sets to remove terms below the training threshold
    print("Filtering validation and test sets to remove terms below training threshold.")
    val_df[propagated_terms_col] = val_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
    test_df[propagated_terms_col] = test_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])

    # Remove rows with no terms after filtering
    val_df = val_df[val_df[propagated_terms_col].apply(len) > 0]
    test_df = test_df[test_df[propagated_terms_col].apply(len) > 0]

    # Check the results after filtering
    filtered_train_counts = Counter([term for terms in train_df[propagated_terms_col].tolist() for term in terms])
    filtered_train_counter_terms_less_than_X = {term: count for term, count in filtered_train_counts.items() if count < min_training_instances}
    print("Filtered function training set terms with less than {} occurrences:".format(min_training_instances), filtered_train_counter_terms_less_than_X)
    print("Filtered function training set total terms:", len(filtered_train_counts))

    return train_df, val_df, test_df, mlb


function_train_df, function_val_df, function_test_df, function_mlb = prepare_data_and_split(function_merged, clusters_col='Cluster_2', terms_col='Raw GO terms')
print("Function training set shape:", function_train_df.shape)
print("Function validation set shape:", function_val_df.shape)
print("Function test set shape:", function_test_df.shape)
print("----")
# Out:
# Processing rows: 100%|██████████| 352461/352461 [00:09<00:00, 37125.60it/s]
# Identifying unique and multi-occurrence clusters
# ShuffleSplit for training, validation, and test sets from multi occurrence clusters
# Extracting rows for each set
# Moving clusters with missing terms from validation/test to training
# Validation terms not in training: set()
# Test terms not in training: set()
# Terms below threshold (50 occurrences): {'GO:0170054', 'GO:0035325', 'GO:0042083', 'GO:0016723', 'GO:0015616', 'GO:0099106', 'GO:0004673', 'GO:0016815', 'GO:0015220', 'GO:0046592', 'GO:0004325', 'GO:0008920', 'GO:0034338', 'GO:0015378', 'GO:0016869', 'GO:0140359', 'GO:0002061', 'GO:0042171', 'GO:0035515', 'GO:0016664', 'GO:0019903', 'GO:0005345', 'GO:0005337', 'GO:0015296', 'GO:0043047', 'GO:0050815', 'GO:0140666', 'GO:0030291', 'GO:0033840', 'GO:0051731', 'GO:0019199', 'GO:0005343', 'GO:0036080', 'GO:0036009', 'GO:0005272', 'GO:0016885', 'GO:0015020', 'GO:0016672', 'GO:0030611', 'GO:0003905', 'GO:0033764', 'GO:0070137', 'GO:0015173', 'GO:0043394', 'GO:0030283', 'GO:0015091', 'GO:0019777', 'GO:0004104', 'GO:0016662', 'GO:0004115', 'GO:0016801', 'GO:0015355', 'GO:0000993', 'GO:0035671', 'GO:0003964', 'GO:0140674', 'GO:0009669', 'GO:0031544', 'GO:0170053', 'GO:0002060', 'GO:0001653', 'GO:0045289', 'GO:0055056', 'GO:0004344', 'GO:0004738', 'GO:0015095', 'GO:0005365', 'GO:0051734', 'GO:0106345', 'GO:0016663', 'GO:0099604', 'GO:0005287', 'GO:0016406', 'GO:0019904', 'GO:0015185', 'GO:0005245', 'GO:0015152', 'GO:0004486', 'GO:0051032', 'GO:0016421', 'GO:0044390', 'GO:0031593', 'GO:0140939', 'GO:0016824', 'GO:0042910', 'GO:0008486', 'GO:0015526', 'GO:0050309', 'GO:0047555', 'GO:0015154', 'GO:0016715', 'GO:0000099', 'GO:0043364', 'GO:0141052', 'GO:0015141', 'GO:0004407', 'GO:0140658', 'GO:0005353', 'GO:0009013', 'GO:0004860', 'GO:0047617', 'GO:0031543', 'GO:0050486', 'GO:0043225', 'GO:0015149', 'GO:0030276', 'GO:0070004', 'GO:0015119', 'GO:0016420', 'GO:0008907', 'GO:0050664', 'GO:0004806', 'GO:0052738', 'GO:0004930', 'GO:0034596', 'GO:0015373', 'GO:0019798', 'GO:0016803', 'GO:0080084', 'GO:0004564', 'GO:0015172', 'GO:0004396', 'GO:0070548', 'GO:0008554', 'GO:0140721', 'GO:0010354', 'GO:0008556', 'GO:0004463', 'GO:0016713', 'GO:0106018', 'GO:0008376', 'GO:0004888', 'GO:0043893', 'GO:0015116', 'GO:0140776', 'GO:0140033', 'GO:0004563', 'GO:0051219', 'GO:0030492', 'GO:0051864', 'GO:0004022', 'GO:0035673', 'GO:0016898', 'GO:0016805', 'GO:0015106', 'GO:0140940', 'GO:0140135', 'GO:0140906', 'GO:0016416', 'GO:0015112', 'GO:0004084', 'GO:0034594', 'GO:0003730', 'GO:0005416', 'GO:0016759', 'GO:0035312', 'GO:0141050', 'GO:0015157', 'GO:0016703', 'GO:0033677', 'GO:0070492', 'GO:0003857', 'GO:0016247', 'GO:0015269', 'GO:0015175', 'GO:0019212', 'GO:0001217', 'GO:0052880', 'GO:0005179', 'GO:0141218', 'GO:0000182', 'GO:0005227', 'GO:0004731', 'GO:0004127', 'GO:0031369', 'GO:0016917', 'GO:0140161', 'GO:0005452', 'GO:0008381', 'GO:0046997', 'GO:0016215', 'GO:0034595', 'GO:0003865', 'GO:0140905', 'GO:0015928', 'GO:0016154', 'GO:0106019', 'GO:0070815', 'GO:0033931', 'GO:0004630', 'GO:0015315', 'GO:0003954', 'GO:0035591', 'GO:0017022', 'GO:0016794', 'GO:0016695', 'GO:0004709', 'GO:0016732', 'GO:0004040', 'GO:0008373', 'GO:0004864', 'GO:0004629', 'GO:0004753', 'GO:0015125', 'GO:0001025', 'GO:0140517', 'GO:0051499', 'GO:0015292', 'GO:0016827', 'GO:1901683', 'GO:0048030', 'GO:0008516', 'GO:0016632', 'GO:0046030', 'GO:0015666', 'GO:0050463', 'GO:0030572', 'GO:0099122', 'GO:0033164', 'GO:0045309', 'GO:0016454', 'GO:0120159', 'GO:0160041', 'GO:0008940', 'GO:0005385', 'GO:0034483', 'GO:0015210', 'GO:0034701', 'GO:0061459', 'GO:0016312', 'GO:0005186', 'GO:0016419', 'GO:0051377', 'GO:0140713', 'GO:0016636', 'GO:0017136', 'GO:0004114', 'GO:0005350', 'GO:0061665', 'GO:0015174', 'GO:0016716', 'GO:0141126', 'GO:0051903', 'GO:0016699', 'GO:0005539', 'GO:0005184', 'GO:0015930', 'GO:0015123', 'GO:0015391', 'GO:0120517', 'GO:0070735', 'GO:0015450', 'GO:0016647', 'GO:0043176', 'GO:0051018', 'GO:0010485', 'GO:0016899', 'GO:0004623', 'GO:0005217', 'GO:0106017', 'GO:0016972', 'GO:0015138', 'GO:0004844', 'GO:0015377', 'GO:0016997', 'GO:0042979', 'GO:0001163', 'GO:0008477', 'GO:0016002', 'GO:0005351', 'GO:0042085', 'GO:0008796', 'GO:0016843', 'GO:0030547', 'GO:0030058', 'GO:0017150', 'GO:0016750', 'GO:0004713', 'GO:0016435', 'GO:0031545', 'GO:0050263', 'GO:0022829', 'GO:0000179 ...
# Filtering out 322 terms from the training set.
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2548981061.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[propagated_terms_col] = train_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
# Filtering validation and test sets to remove terms below training threshold.
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2548981061.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df[propagated_terms_col] = val_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2548981061.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[propagated_terms_col] = test_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
# Filtered function training set terms with less than 50 occurrences: {}
# Filtered function training set total terms: 744
# Function training set shape: (289930, 14)
# Function validation set shape: (29188, 14)
# Function test set shape: (33343, 14)
# ----

# %%
component_train_df, component_val_df, component_test_df, component_mlb = prepare_data_and_split(component_merged, clusters_col='Cluster_2', terms_col='Raw GO terms')
# Out:
# Processing rows: 100%|██████████| 304567/304567 [00:08<00:00, 37979.03it/s]
# Identifying unique and multi-occurrence clusters
# ShuffleSplit for training, validation, and test sets from multi occurrence clusters
# Extracting rows for each set
# Moving clusters with missing terms from validation/test to training
# Validation terms not in training: set()
# Test terms not in training: set()
# Terms below threshold (50 occurrences): {'GO:0005765', 'GO:0005775', 'GO:0008278', 'GO:0017053', 'GO:0033061', 'GO:0019897', 'GO:0065010', 'GO:0000775', 'GO:0005789', 'GO:0097729', 'GO:0030863', 'GO:0034705', 'GO:0000322', 'GO:0032116', 'GO:0031514', 'GO:0098802', 'GO:0038037', 'GO:0051286', 'GO:0042646', 'GO:0055028', 'GO:0005876', 'GO:0016459', 'GO:0005618', 'GO:1902687', 'GO:0098857', 'GO:0002178', 'GO:0070112', 'GO:0000164', 'GO:0097651', 'GO:0033655', 'GO:0009527', 'GO:0043190', 'GO:0030141', 'GO:0010009', 'GO:0031519', 'GO:0098636', 'GO:0097648', 'GO:0098858', 'GO:0043235', 'GO:0005657', 'GO:0034706', 'GO:0031010', 'GO:0030427', 'GO:1990391', 'GO:0036387', 'GO:0016465', 'GO:0044094', 'GO:0032156', 'GO:0031082', 'GO:0098562', 'GO:0030312', 'GO:0005737', 'GO:0005634', 'GO:0000785', 'GO:0090545', 'GO:0030055', 'GO:0071014', 'GO:0030076', 'GO:0000177', 'GO:0005798', 'GO:0090576', 'GO:0060187', 'GO:0043264', 'GO:1905862', 'GO:0030136', 'GO:0000783', 'GO:0043659', 'GO:0042709', 'GO:0005891', 'GO:0044297', 'GO:0098827', 'GO:0043230', 'GO:0005816', 'GO:0000235', 'GO:0043660', 'GO:0008076', 'GO:0000782', 'GO:0036125', 'GO:0000940', 'GO:0072379', 'GO:0000792', 'GO:0070419', 'GO:0044232', 'GO:0071782', 'GO:0005783', 'GO:0080008', 'GO:0005742', 'GO:0044796', 'GO:0009526', 'GO:0098576', 'GO:0030133'}
# Filtering out 91 terms from the training set.
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2548981061.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[propagated_terms_col] = train_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2548981061.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df[propagated_terms_col] = val_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2548981061.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[propagated_terms_col] = test_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
# Filtering validation and test sets to remove terms below training threshold.
# Filtered function training set terms with less than 50 occurrences: {}
# Filtered function training set total terms: 255

# %%
process_train_df, process_val_df, process_test_df, process_mlb = prepare_data_and_split(process_merged, clusters_col='Cluster_2', terms_col='Raw GO terms')
# Out:
# Processing rows: 100%|██████████| 279033/279033 [00:06<00:00, 40265.36it/s]
# Identifying unique and multi-occurrence clusters
# ShuffleSplit for training, validation, and test sets from multi occurrence clusters
# Extracting rows for each set
# Moving clusters with missing terms from validation/test to training
# Validation terms not in training: set()
# Test terms not in training: set()
# Terms below threshold (50 occurrences): {'GO:0006060', 'GO:0019835', 'GO:1901028', 'GO:0044406', 'GO:0051336', 'GO:0030335', 'GO:0043062', 'GO:0006116', 'GO:0033567', 'GO:0000103', 'GO:0009690', 'GO:1901159', 'GO:0098656', 'GO:0043447', 'GO:0015766', 'GO:0051056', 'GO:0006426', 'GO:0031589', 'GO:0017121', 'GO:0042399', 'GO:0046271', 'GO:0035725', 'GO:1902115', 'GO:0051231', 'GO:1904030', 'GO:0031554', 'GO:0070601', 'GO:0006864', 'GO:1903522', 'GO:0008016', 'GO:0009217', 'GO:0071709', 'GO:0042044', 'GO:0045595', 'GO:0010466', 'GO:0042173', 'GO:0052553', 'GO:0009303', 'GO:1900704', 'GO:0099046', 'GO:0050804', 'GO:0043954', 'GO:0033875', 'GO:0016310', 'GO:0006600', 'GO:0031365', 'GO:1901873', 'GO:0006801', 'GO:0030653', 'GO:0044088', 'GO:0045785', 'GO:0051446', 'GO:0034410', 'GO:0006523', 'GO:0120178', 'GO:0009146', 'GO:0042938', 'GO:0071900', 'GO:1903312', 'GO:0006208', 'GO:1903321', 'GO:0042127', 'GO:0010507', 'GO:0030334', 'GO:0035795', 'GO:1902410', 'GO:0140718', 'GO:0007548', 'GO:0042365', 'GO:0140467', 'GO:0006289', 'GO:0033619', 'GO:0043066', 'GO:0015879', 'GO:0051051', 'GO:0006671', 'GO:0046444', 'GO:0006064', 'GO:0051588', 'GO:0045123', 'GO:0044355', 'GO:0048608', 'GO:0001819', 'GO:0055062', 'GO:0010467', 'GO:0052372', 'GO:0035442', 'GO:0019043', 'GO:0006177', 'GO:0016441', 'GO:0015669', 'GO:0034411', 'GO:0031122', 'GO:0051495', 'GO:1901678', 'GO:0051126', 'GO:0051790', 'GO:0032456', 'GO:1901970', 'GO:0006468', 'GO:0006584', 'GO:0015947', 'GO:0071969', 'GO:0009306', 'GO:0009310', 'GO:0045337', 'GO:0001523', 'GO:0072340', 'GO:0010570', 'GO:0072598', 'GO:0008211', 'GO:0002573', 'GO:0061620', 'GO:0009612', 'GO:0052173', 'GO:0051094', 'GO:0070596', 'GO:0007169', 'GO:0009136', 'GO:0010476', 'GO:1990849', 'GO:0009953', 'GO:0051788', 'GO:0006829', 'GO:0141060', 'GO:0008204', 'GO:0009093', 'GO:0019401', 'GO:0006216', 'GO:0006077', 'GO:0050871', 'GO:0019376', 'GO:0072388', 'GO:0006706', 'GO:0046108', 'GO:0019585', 'GO:0046436', 'GO:0009237', 'GO:0009409', 'GO:0048580', 'GO:0019530', 'GO:0006415', 'GO:1905709', 'GO:0044872', 'GO:0097292', 'GO:1900373', 'GO:0035461', 'GO:0043549', 'GO:0048609', 'GO:0048513', 'GO:0051262', 'GO:0002694', 'GO:0099177', 'GO:0046928', 'GO:0018342', 'GO:0017001', 'GO:0051938', 'GO:0018200', 'GO:0019586', 'GO:0071763', 'GO:2001239', 'GO:0006308', 'GO:0031456', 'GO:0046484', 'GO:0044057', 'GO:1903320', 'GO:0050778', 'GO:0030810', 'GO:0001120', 'GO:0090069', 'GO:0002696', 'GO:0000098', 'GO:0009698', 'GO:2001293', 'GO:0072490', 'GO:0043570', 'GO:0043112', 'GO:0018201', 'GO:0090481', 'GO:0002685', 'GO:0032527', 'GO:0060296', 'GO:0046462', 'GO:0030968', 'GO:0042373', 'GO:2000220', 'GO:0000730', 'GO:0045981', 'GO:0030473', 'GO:0030307', 'GO:2000765', 'GO:0097354', 'GO:0017003', 'GO:0090169', 'GO:0016094', 'GO:0042374', 'GO:0010039', 'GO:0006497', 'GO:0050790', 'GO:0050731', 'GO:0006955', 'GO:0042157', 'GO:0006517', 'GO:0006693', 'GO:0019605', 'GO:0046461', 'GO:0016259', 'GO:0002700', 'GO:0050867', 'GO:0140205', 'GO:0065009', 'GO:0034053', 'GO:0009791', 'GO:0002130', 'GO:0016032', 'GO:0050654', 'GO:0033673', 'GO:0046452', 'GO:0032785', 'GO:2000222', 'GO:1900377', 'GO:0009120', 'GO:0019406', 'GO:0072351', 'GO:0006531', 'GO:0006857', 'GO:1903799', 'GO:0006491', 'GO:1901337', 'GO:0072338', 'GO:0002687', 'GO:0051300', 'GO:0046149', 'GO:0071966', 'GO:1903173', 'GO:0097190', 'GO:0071589', 'GO:0051642', 'GO:0030201', 'GO:0009617', 'GO:0052548', 'GO:0048468', 'GO:0030212', 'GO:1903726', 'GO:0019934', 'GO:0070784', 'GO:0046464', 'GO:0006901', 'GO:1901910', 'GO:0032881', 'GO:0032986', 'GO:0046070', 'GO:0030449', 'GO:0048582', 'GO:0051230', 'GO:0008217', 'GO:0048469', 'GO:0051301', 'GO:0018131', 'GO:1902905', 'GO:0009696', 'GO:0040011', 'GO:0097052', 'GO:0097164', 'GO:0071322', 'GO:0070880', 'GO:0070252', 'GO:0099024', 'GO:1902373', 'GO:1902751', 'GO:0070199', 'GO:0140053', 'GO:0006820', 'GO:0018210', 'GO:0009140', 'GO:0070598', 'GO:0006515', 'GO:0010594', 'GO:0015876', 'GO:0008589', 'GO:0051047', 'GO:0033212', 'GO:0030493 ...
# Filtering out 1050 terms from the training set.
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2548981061.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[propagated_terms_col] = train_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2548981061.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df[propagated_terms_col] = val_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
# Filtering validation and test sets to remove terms below training threshold.
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2548981061.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[propagated_terms_col] = test_df[propagated_terms_col].apply(lambda terms: [term for term in terms if term not in terms_below_threshold])
# Filtered function training set terms with less than 50 occurrences: {}
# Filtered function training set total terms: 1548

# %%
#how many GO terms are there in the propogated colmmn for function train
temp_terms = function_train_df['Raw propagated GO terms'].tolist()
#flatten the list
temp_terms = [item for sublist in temp_terms for item in sublist]
print("Total number of GO terms in the function training set:", len(temp_terms))
#unique terms
print("Total number of unique GO terms in the function training set:", len(set(temp_terms)))
# Out:
# Total number of GO terms in the function training set: 3096062
# Total number of unique GO terms in the function training set: 744

# %%
#are there any terms that are not in the training set but are in the validation set and test set

temp_terms_train = function_train_df['Propagated GO terms'].tolist()
temp_terms_train = [item for sublist in temp_terms_train for item in sublist]
temp_terms_val = function_val_df['Propagated GO terms'].tolist()
temp_terms_val = [item for sublist in temp_terms_val for item in sublist]
temp_terms_test = function_test_df['Propagated GO terms'].tolist()
temp_terms_test = [item for sublist in temp_terms_test for item in sublist]

print("Terms in validation set but not in training set:", set(temp_terms_val) - set(temp_terms_train))
print("Terms in test set but not in training set:", set(temp_terms_test) - set(temp_terms_train))
# Out:
# Terms in validation set but not in training set: set()
# Terms in test set but not in training set: set()

# %%
os.chdir("/PFP_PUBLISH/processed_data_90_30")
function_train_df.to_csv("function_train.tsv", sep="\t", index=False)
function_val_df.to_csv("function_val.tsv", sep="\t", index=False)
function_test_df.to_csv("function_test.tsv", sep="\t", index=False)

component_train_df.to_csv("component_train.tsv", sep="\t", index=False)
component_val_df.to_csv("component_val.tsv", sep="\t", index=False)
component_test_df.to_csv("component_test.tsv", sep="\t", index=False)

process_train_df.to_csv("process_train.tsv", sep="\t", index=False)
process_val_df.to_csv("process_val.tsv", sep="\t", index=False)
process_test_df.to_csv("process_test.tsv", sep="\t", index=False)

#write file that has contains how many unique GO terms are in the training set
function_train_terms = function_train_df['Raw propagated GO terms'].tolist()
function_train_terms = [item for sublist in function_train_terms for item in sublist]
component_train_terms = component_train_df['Raw propagated GO terms'].tolist()
component_train_terms = [item for sublist in component_train_terms for item in sublist]
process_train_terms = process_train_df['Raw propagated GO terms'].tolist()
process_train_terms = [item for sublist in process_train_terms for item in sublist]
function_train_terms_unique = len(set(function_train_terms))
component_train_terms_unique = len(set(component_train_terms))
process_train_terms_unique = len(set(process_train_terms))

with open("number_of_terms_trained_on.txt", "w") as f:
    print("Function:", len(set(function_train_terms)), file=f)
    print("Component:", len(set(component_train_terms)), file=f)
    print("Process:", len(set(process_train_terms)), file=f)

# %%
with open("df_shapes.txt", "w") as f:
    print("Function train:", function_train_df.shape, file=f)
    print("Function val:", function_val_df.shape, file=f)
    print("Function test:", function_test_df.shape, file=f)
    print("Component train:", component_train_df.shape, file=f)
    print("Component val:", component_val_df.shape, file=f)
    print("Component test:", component_test_df.shape, file=f)
    print("Process train:", process_train_df.shape, file=f)
    print("Process val:", process_val_df.shape, file=f)
    print("Process test:", process_test_df.shape, file=f)

# %%
function_merged.to_csv("presplit_function_merged.tsv", sep="\t", index=False)
component_merged.to_csv("presplit_component_merged.tsv", sep="\t", index=False)
process_merged.to_csv("presplit_process_merged.tsv", sep="\t", index=False)

# %%
assert len(function_train_df) + len(function_val_df) + len(function_test_df) == len(function_merged)
assert len(component_train_df) + len(component_val_df) + len(component_test_df) == len(component_merged)
assert len(process_train_df) + len(process_val_df) + len(process_test_df) == len(process_merged)

# %%
#create fasta files 
seq_records_function_train = create_seq_records(function_train_df)
seq_records_function_val = create_seq_records(function_val_df)
seq_records_function_test = create_seq_records(function_test_df)

seq_records_component_train = create_seq_records(component_train_df)
seq_records_component_val = create_seq_records(component_val_df)
seq_records_component_test = create_seq_records(component_test_df)

seq_records_process_train = create_seq_records(process_train_df)
seq_records_process_val = create_seq_records(process_val_df)
seq_records_process_test = create_seq_records(process_test_df)

assert len(seq_records_function_train) == function_train_df.shape[0]
assert len(seq_records_function_val) == function_val_df.shape[0]
assert len(seq_records_function_test) == function_test_df.shape[0]

assert len(seq_records_component_train) == component_train_df.shape[0]
assert len(seq_records_component_val) == component_val_df.shape[0]
assert len(seq_records_component_test) == component_test_df.shape[0]

assert len(seq_records_process_train) == process_train_df.shape[0]
assert len(seq_records_process_val) == process_val_df.shape[0]
assert len(seq_records_process_test) == process_test_df.shape[0]

# %%
#write out the fasta files
SeqIO.write(seq_records_function_train, "function_train.fasta", "fasta")
SeqIO.write(seq_records_function_val, "function_val.fasta", "fasta")
SeqIO.write(seq_records_function_test, "function_test.fasta", "fasta")

SeqIO.write(seq_records_component_train, "component_train.fasta", "fasta")
SeqIO.write(seq_records_component_val, "component_val.fasta", "fasta")
SeqIO.write(seq_records_component_test, "component_test.fasta", "fasta")

SeqIO.write(seq_records_process_train, "process_train.fasta", "fasta")
SeqIO.write(seq_records_process_val, "process_val.fasta", "fasta")
SeqIO.write(seq_records_process_test, "process_test.fasta", "fasta")
# Out:
# 26746

# %% [markdown]
# # Recreate ancestors dict with the terms trained on

# %% [markdown]
# This needs to be done since there are ancestors that are introduced that are not part of the unique GO terms.
#
# For example GO term X is present in the pre-propogated dataset. Y is a parent of X. Y is not a key then in the existing dict configuration.

# %%
len(set(function_train_terms)), len(component_mlb.classes_), len(process_mlb.classes_)
# Out:
# (744, 809, 2287)

# %%
batch_size = 50  # You can adjust the batch size here

UNIQUE_FUNCTION_TERMS = list(set(function_train_terms))
UNIQUE_COMPONENT_TERMS = list(set(component_train_terms))
UNIQUE_PROCESS_TERMS = list(set(process_train_terms))

trained_function_json_dict, trained_function_ancestors_dict = process_go_terms_in_batches(UNIQUE_FUNCTION_TERMS, batch_size=batch_size)
assert len(trained_function_json_dict) == len(UNIQUE_FUNCTION_TERMS)

trained_component_json_dict, trained_component_ancestors_dict = process_go_terms_in_batches(UNIQUE_COMPONENT_TERMS, batch_size=batch_size)
assert len(trained_component_json_dict) == len(UNIQUE_COMPONENT_TERMS)

trained_process_json_dict, trained_process_ancestors_dict = process_go_terms_in_batches(UNIQUE_PROCESS_TERMS, batch_size=batch_size)
assert len(trained_process_json_dict) == len(UNIQUE_PROCESS_TERMS)

with open('trained_function_ALL_data_ancestors_dict.json', 'w') as f:
    json.dump(trained_function_ancestors_dict, f, indent=4)

with open('trained_function_ALL_data_json_dict.json', 'w') as f:
    json.dump(trained_function_json_dict, f, indent=4)

with open('trained_component_ALL_data_ancestors_dict.json', 'w') as f:
    json.dump(trained_component_ancestors_dict, f, indent=4)

with open('trained_component_ALL_data_json_dict.json', 'w') as f:
    json.dump(trained_component_json_dict, f, indent=4)

with open('trained_process_ALL_data_ancestors_dict.json', 'w') as f:
    json.dump(trained_process_ancestors_dict, f, indent=4)

with open('trained_process_ALL_data_json_dict.json', 'w') as f:
    json.dump(trained_process_json_dict, f, indent=4)
# Out:
# 100%|██████████| 15/15 [00:15<00:00,  1.01s/it]
# 100%|██████████| 6/6 [00:05<00:00,  1.19it/s]
# 100%|██████████| 31/31 [00:27<00:00,  1.12it/s]

# %% [markdown]
# # Get embeddings

# %%
#function numpy array
function_all_np = np.load("TM_vec_embeddings/reduced_90_function_TM_Vec.npy", allow_pickle=True)
function_all_df = pd.read_csv("/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_function.tsv", sep='\t')
assert function_all_np.shape[0] == function_all_df.shape[0]

#component numpy array
component_all_np = np.load("TM_vec_embeddings/reduced_90_component_TM_Vec.npy", allow_pickle=True)
component_all_df = pd.read_csv("/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_component.tsv", sep='\t')
assert component_all_np.shape[0] == component_all_df.shape[0]

#process numpy array
process_all_np = np.load("TM_vec_embeddings/reduced_90_process_TM_Vec.npy", allow_pickle=True)
process_all_df = pd.read_csv("/Users/harsh/Documents/PFP_PUBLISH/raw_data_from_uniprot/reduced_90_process.tsv", sep='\t')
assert process_all_np.shape[0] == process_all_df.shape[0]

# %%
function_all_dict = dict(zip(function_all_df['Entry'], function_all_np))
component_all_dict = dict(zip(component_all_df['Entry'], component_all_np))
process_all_dict = dict(zip(process_all_df['Entry'], process_all_np))

function_train_np = np.array([function_all_dict[entry] for entry in function_train_df['Entry']])
function_val_np = np.array([function_all_dict[entry] for entry in function_val_df['Entry']])
function_test_np = np.array([function_all_dict[entry] for entry in function_test_df['Entry']])

component_train_np = np.array([component_all_dict[entry] for entry in component_train_df['Entry']])
component_val_np = np.array([component_all_dict[entry] for entry in component_val_df['Entry']])
component_test_np = np.array([component_all_dict[entry] for entry in component_test_df['Entry']])

process_train_np = np.array([process_all_dict[entry] for entry in process_train_df['Entry']])
process_val_np = np.array([process_all_dict[entry] for entry in process_val_df['Entry']])
process_test_np = np.array([process_all_dict[entry] for entry in process_test_df['Entry']])

assert function_train_np.shape[0] == function_train_df.shape[0]
assert function_val_np.shape[0] == function_val_df.shape[0]
assert function_test_np.shape[0] == function_test_df.shape[0]

assert component_train_np.shape[0] == component_train_df.shape[0]
assert component_val_np.shape[0] == component_val_df.shape[0]
assert component_test_np.shape[0] == component_test_df.shape[0]

assert process_train_np.shape[0] == process_train_df.shape[0]
assert process_val_np.shape[0] == process_val_df.shape[0]
assert process_test_np.shape[0] == process_test_df.shape[0]

# %%
np.save("function_train.npy", function_train_np)
np.save("function_val.npy", function_val_np)
np.save("function_test.npy", function_test_np)

np.save("component_train.npy", component_train_np)
np.save("component_val.npy", component_val_np)
np.save("component_test.npy", component_test_np)

np.save("process_train.npy", process_train_np)
np.save("process_val.npy", process_val_np)
np.save("process_test.npy", process_test_np)

#file with expected shapes of embeddings 
with open("expected_shapes.txt", "w") as f:
    print("Function train:", function_train_np.shape, file=f)
    print("Function val:", function_val_np.shape, file=f)
    print("Function test:", function_test_np.shape, file=f)
    print("Component train:", component_train_np.shape, file=f)
    print("Component val:", component_val_np.shape, file=f)
    print("Component test:", component_test_np.shape, file=f)
    print("Process train:", process_train_np.shape, file=f)
    print("Process val:", process_val_np.shape, file=f)
    print("Process test:", process_test_np.shape, file=f)

# %% [markdown]
# # Work with the Plasmodium Sequences now

# %%
function_train_terms = function_train_df['Raw propagated GO terms'].tolist()
function_train_terms = [item for sublist in function_train_terms for item in sublist]
function_train_terms = list(set(function_train_terms))
print("Total number of GO terms in the function training set:", len(function_train_terms))

component_train_terms = component_train_df['Raw propagated GO terms'].tolist()
component_train_terms = [item for sublist in component_train_terms for item in sublist]
component_train_terms = list(set(component_train_terms))
print("Total number of GO terms in the component training set:", len(component_train_terms))

process_train_terms = process_train_df['Raw propagated GO terms'].tolist()
process_train_terms = [item for sublist in process_train_terms for item in sublist]
process_train_terms = list(set(process_train_terms))
print("Total number of GO terms in the process training set:", len(process_train_terms))
# Out:
# Total number of GO terms in the function training set: 744
# Total number of GO terms in the component training set: 255
# Total number of GO terms in the process training set: 1548

# %%
#sequences for Plasmodium MA to embedd 
Plasmodium_MA_seqs = create_seq_records(Plasmodium_MA)
SeqIO.write(Plasmodium_MA_seqs, "Plasmodium_MA_ALL.fasta", "fasta")

Plasmodium_MA_function = Plasmodium_MA[Plasmodium_MA["Gene Ontology (molecular function)"].notnull()]
Plasmodium_MA_process = Plasmodium_MA[Plasmodium_MA["Gene Ontology (biological process)"].notnull()]
Plasmodium_MA_component = Plasmodium_MA[Plasmodium_MA["Gene Ontology (cellular component)"].notnull()]

print(Plasmodium_MA_function.shape)
print(Plasmodium_MA_process.shape)
print(Plasmodium_MA_component.shape)
# Out:
# (1328, 9)
# (1360, 9)
# (1413, 9)

# %%
#propogate the annotations for each of the datasets
Plasmodium_MA_function['Raw GO terms'] = Plasmodium_MA_function['Gene Ontology (molecular function)'].str.findall(r"GO:\d+")
Plasmodium_MA_process['Raw GO terms'] = Plasmodium_MA_process['Gene Ontology (biological process)'].str.findall(r"GO:\d+")
Plasmodium_MA_component['Raw GO terms'] = Plasmodium_MA_component['Gene Ontology (cellular component)'].str.findall(r"GO:\d+")

Plasmodium_MA_function_raw_terms_propogated = add_ancestors(list(Plasmodium_MA_function['Raw GO terms']), function_ancestors_dict)
Plasmodium_MA_process_raw_terms_propogated = add_ancestors(list(Plasmodium_MA_process['Raw GO terms']), process_ancestors_dict)
Plasmodium_MA_component_raw_terms_propogated = add_ancestors(list(Plasmodium_MA_component['Raw GO terms']), component_ancestors_dict)

Plasmodium_MA_function['Raw propagated GO terms'] = Plasmodium_MA_function_raw_terms_propogated
Plasmodium_MA_process['Raw propagated GO terms'] = Plasmodium_MA_process_raw_terms_propogated
Plasmodium_MA_component['Raw propagated GO terms'] = Plasmodium_MA_component_raw_terms_propogated
# Out:
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2354573566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Plasmodium_MA_function['Raw GO terms'] = Plasmodium_MA_function['Gene Ontology (molecular function)'].str.findall(r"GO:\d+")
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2354573566.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Plasmodium_MA_process['Raw GO terms'] = Plasmodium_MA_process['Gene Ontology (biological process)'].str.findall(r"GO:\d+")
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2354573566.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Plasmodium_MA_component['Raw GO terms'] = Plasmodium_MA_component['Gene Ontology (cellular component)'].str.findall(r"GO:\d+")
# Adding ancestors: 100%|██████████| 1328/1328 [00:00<00:00, 153842.89it/s]
# Adding ancestors: 100%|██████████| 1360/1360 [00:00<00:00, 214067.38it/s]
# Adding ancestors: 100%|██████████| 1413/1413 [00:00<00:00, 300382.74it/s]
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2354573566.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Plasmodium_MA_function['Raw propagated GO terms'] = Plasmodium_MA_function_raw_terms_propogated
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2354573566.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Plasmodium_MA_process['Raw propagated GO terms'] = Plasmodium_MA_process_raw_terms_propogated
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/2354573566.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Plasmodium_MA_component['Raw propagated GO terms'] = Plasmodium_MA_component_raw_terms_propogated

# %%
#In the propogated terms, how many unique terms are present there but not in the training set
Plasmodium_MA_function_raw_terms_propogated_unique = Plasmodium_MA_function['Raw propagated GO terms'].tolist()
Plasmodium_MA_function_raw_terms_propogated_unique = [item for sublist in Plasmodium_MA_function_raw_terms_propogated_unique for item in sublist]
Plasmodium_MA_function_raw_terms_propogated_unique = list(set(Plasmodium_MA_function_raw_terms_propogated_unique))
unique_terms_not_in_training_function = set(Plasmodium_MA_function_raw_terms_propogated_unique) - set(function_train_terms)
print("Unique terms in Plasmodium MA function propogated terms but not in the training set:", len(unique_terms_not_in_training_function))

Plasmodium_MA_process_raw_terms_propogated = Plasmodium_MA_process['Raw propagated GO terms'].tolist()
Plasmodium_MA_process_raw_terms_propogated = [item for sublist in Plasmodium_MA_process_raw_terms_propogated for item in sublist]
Plasmodium_MA_process_raw_terms_propogated = list(set(Plasmodium_MA_process_raw_terms_propogated))
unique_terms_not_in_training_process = set(Plasmodium_MA_process_raw_terms_propogated) - set(process_train_terms)
print("Unique terms in Plasmodium MA process propogated terms but not in the training set:", len(unique_terms_not_in_training_process))

Plasmodium_MA_component_raw_terms_propogated = Plasmodium_MA_component['Raw propagated GO terms'].tolist()
Plasmodium_MA_component_raw_terms_propogated = [item for sublist in Plasmodium_MA_component_raw_terms_propogated for item in sublist]
Plasmodium_MA_component_raw_terms_propogated = list(set(Plasmodium_MA_component_raw_terms_propogated))
unique_terms_not_in_training_component = set(Plasmodium_MA_component_raw_terms_propogated) - set(component_train_terms)
print("Unique terms in Plasmodium MA component propogated terms but not in the training set:", len(unique_terms_not_in_training_component))
# Out:
# Unique terms in Plasmodium MA function propogated terms but not in the training set: 55
# Unique terms in Plasmodium MA process propogated terms but not in the training set: 233
# Unique terms in Plasmodium MA component propogated terms but not in the training set: 21

# %%
# #filter out terms in raw propogated terms that are not in the unique_terms_not_in_training_function
# Plasmodium_MA_function['Raw propagated GO terms'] = Plasmodium_MA_function['Raw propagated GO terms'].apply(lambda terms: [term for term in terms if term not in unique_terms_not_in_training_function])
# Plasmodium_MA_process['Raw propagated GO terms'] = Plasmodium_MA_process['Raw propagated GO terms'].apply(lambda terms: [term for term in terms if term not in unique_terms_not_in_training_function])
# Plasmodium_MA_component['Raw propagated GO terms'] = Plasmodium_MA_component['Raw propagated GO terms'].apply(lambda terms: [term for term in terms if term not in unique_terms_not_in_training_function])
# Out:
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/997023908.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Plasmodium_MA_function['Raw propagated GO terms'] = Plasmodium_MA_function['Raw propagated GO terms'].apply(lambda terms: [term for term in terms if term not in unique_terms_not_in_training_function])
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/997023908.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Plasmodium_MA_process['Raw propagated GO terms'] = Plasmodium_MA_process['Raw propagated GO terms'].apply(lambda terms: [term for term in terms if term not in unique_terms_not_in_training_function])
# /var/folders/ky/jqpqz88565l8qdqz4jf3387c0000gn/T/ipykernel_61963/997023908.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Plasmodium_MA_component['Raw propagated GO terms'] = Plasmodium_MA_component['Raw propagated GO terms'].apply(lambda terms: [term for term in terms if term not in unique_terms_not_in_training_function])

# %%
#first print the original shape 
print("Original shapes:")
print("Function:", Plasmodium_MA_function.shape)
print("Process:", Plasmodium_MA_process.shape)
print("Component:", Plasmodium_MA_component.shape)

Plasmodium_MA_function = Plasmodium_MA_function[Plasmodium_MA_function['Raw propagated GO terms'].str.len() > 0]
Plasmodium_MA_process = Plasmodium_MA_process[Plasmodium_MA_process['Raw propagated GO terms'].str.len() > 0]
Plasmodium_MA_component = Plasmodium_MA_component[Plasmodium_MA_component['Raw propagated GO terms'].str.len() > 0]

print("After filtering out terms not in the training set:")
print("Function:", Plasmodium_MA_function.shape)
print("Process:", Plasmodium_MA_process.shape)
print("Component:", Plasmodium_MA_component.shape)
# Out:
# Original shapes:
# Function: (1328, 11)
# Process: (1360, 11)
# Component: (1413, 11)
# After filtering out terms not in the training set:
# Function: (1328, 11)
# Process: (1355, 11)
# Component: (1410, 11)

# %%
Plasmodium_MA_embedd_all = np.load("/Users/harsh/Documents/PFP_PUBLISH/processed_data_90_30/TM_vec_embeddings/Plasmodium_MA_TM_Vec.npy", allow_pickle=True)
print(Plasmodium_MA_embedd_all.shape)
Plasmodium_MA_ids = Plasmodium_MA['Entry'].tolist()

Plasmodium_MA_dict = dict(zip(Plasmodium_MA_ids, Plasmodium_MA_embedd_all))
# Out:
# (1527, 512)

# %%
#filter the dict based on the entries in the Plasmodium_MA_function, Plasmodium_MA_process, and Plasmodium_MA_component
Plasmodium_MA_function_np = np.array([Plasmodium_MA_dict[entry] for entry in Plasmodium_MA_function['Entry']])
Plasmodium_MA_process_np = np.array([Plasmodium_MA_dict[entry] for entry in Plasmodium_MA_process['Entry']])
Plasmodium_MA_component_np = np.array([Plasmodium_MA_dict[entry] for entry in Plasmodium_MA_component['Entry']])

assert Plasmodium_MA_function_np.shape[0] == Plasmodium_MA_function.shape[0]
assert Plasmodium_MA_process_np.shape[0] == Plasmodium_MA_process.shape[0]
assert Plasmodium_MA_component_np.shape[0] == Plasmodium_MA_component.shape[0]

np.save("Plasmodium_MA_function.npy", Plasmodium_MA_function_np)
np.save("Plasmodium_MA_process.npy", Plasmodium_MA_process_np)
np.save("Plasmodium_MA_component.npy", Plasmodium_MA_component_np)

#save the dataframes
Plasmodium_MA_function.to_csv("Plasmodium_MA_function.tsv", sep="\t", index=False)
Plasmodium_MA_process.to_csv("Plasmodium_MA_process.tsv", sep="\t", index=False)
Plasmodium_MA_component.to_csv("Plasmodium_MA_component.tsv", sep="\t", index=False)

# %%
Plasmodium_MA_function_seqs = create_seq_records(Plasmodium_MA_function)
Plasmodium_MA_process_seqs = create_seq_records(Plasmodium_MA_process)
Plasmodium_MA_component_seqs = create_seq_records(Plasmodium_MA_component)

# %%
SeqIO.write(Plasmodium_MA_function_seqs, "Plasmodium_MA_function.fasta", "fasta")
SeqIO.write(Plasmodium_MA_process_seqs, "Plasmodium_MA_process.fasta", "fasta")
SeqIO.write(Plasmodium_MA_component_seqs, "Plasmodium_MA_component.fasta", "fasta")
# Out:
# 1410

# %% [markdown]
# # Generate IA TSV using the training data

# %%
function_train_df_subset = total_SAR_function_GO[['Entry', 'Raw GO terms']].copy()
function_train_df_subset.columns = ['EntryID', 'term']

component_train_df_subset = total_SAR_component_GO[['Entry', 'Raw GO terms']].copy()
component_train_df_subset.columns = ['EntryID', 'term']

process_train_df_subset = total_SAR_process_GO[['Entry', 'Raw GO terms']].copy()
process_train_df_subset.columns = ['EntryID', 'term']

# Adding aspect to each respective dataframe
function_train_df_subset['aspect'] = 'MFO'
component_train_df_subset['aspect'] = 'CCO'
process_train_df_subset['aspect'] = 'BPO'

# Concatenating all dataframes to create a final combined dataframe
combined_df = pd.concat([function_train_df_subset, component_train_df_subset, process_train_df_subset], ignore_index=True)

exploded_df = combined_df.explode('term')

exploded_df.head()

#REMOVE ALL_OBSELETE_TERMS
exploded_df = exploded_df[~exploded_df['term'].isin(ALL_OBSELETE_TERMS)]

# %%
exploded_df.to_csv("terms_for_IA_calculation.tsv", sep="\t", index=False)

# %% [markdown]
# python ia.py -a /Users/harsh/Documents/PFP_PUBLISH/terms_for_IA_calculation.tsv -o /Users/harsh/Documents/PFP_PUBLISH/IA_all.tsv -g /Users/harsh/Documents/PFP_PUBLISH/go-basic.obo
